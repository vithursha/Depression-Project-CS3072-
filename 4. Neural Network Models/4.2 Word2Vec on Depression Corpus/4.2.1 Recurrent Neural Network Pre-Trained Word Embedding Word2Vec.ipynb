# %% [markdown]
# #(LSTM) Pre-Trained Word Embedding Word2Vec

# %% [markdown]
# ###Reference
# data representation techniques (Tokenizer() class, Word2Vec and GloVe embedding): 'Deep Learning with Python' by Francois Chollet, 'Implement neural networks with Keras on Theano and TensorFlow' by Sujit Pal et al.
#
# spam detection example: https://towardsdatascience.com/nlp-spam-detection-in-sms-text-data-using-deep-learning-b8632db85cc8
#
# recurrent layers: https://keras.io/api/layers/recurrent_layers/

# %% [markdown]
# ###Mounting to Google Drive

# %%
#connecting gdrive into the google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Import Libraries

# %%
# import libraries
import pandas as pd
import gensim
import nltk
nltk.download('punkt')
import os
import numpy as np
import tensorflow as tf
from keras.constraints import max_norm

from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers.recurrent import LSTM
from keras.layers import Activation, Dense, Dropout, Flatten, SimpleRNN
from keras.initializers import Constant
from tensorflow.keras import layers
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score
from sklearn.metrics import classification_report
import seaborn as sns


from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from tensorflow.keras.utils import plot_model
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ####Load the Dataset

# %%
#load the dataset - change the file path 
data=pd.read_csv("/content/gdrive/MyDrive/Depression Project/DepressionDataFinal2Processed.csv")
data = data.astype(str)
data["Target"] = data["Target"].astype(str).astype(int)
data.head()
# Out:
#          Id                                            Text  Target
# 0  2.85e+17   one thing love life mother one ever come mine       1
# 1   2.9e+17                         want perfect want happy       0
# 2  2.86e+17  mom hates dad hates today sucks fword life tho       0
# 3  2.86e+17                                  hate hate life       0
# 4  2.86e+17                                       feel good       1

# %%
data.columns
# Out:
# Index(['Id', 'Text', 'Target'], dtype='object')

# %% [markdown]
# ### Train, Val, Test split --> 60%, 20%, 20%

# %%
# train, val, test split --> 60%, 20%, 20% 
# x_train is the training data set
# y_test is the corresponding labels to x_train 
# x_test is the test dataset 
# y_test is the corresponding label to x_test 
x_train, x_test, y_train, y_test = train_test_split(data, data.Target, test_size=0.2, random_state=1)
# # 0.25 x 0.8 = 0.2
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=1)

# %% [markdown]
# ### Constants

# %%
max_len = 20
EMBEDDING_DIM = 100

# %% [markdown]
# ### Tokenize tweets using Tokenizer()

# %%
# Tokenizer API used to encode each word as a number 
vect = Tokenizer()
total_reviews = x_train + x_test + x_val
vect.fit_on_texts(total_reviews)

# %% [markdown]
# ### Turn the Vectorized Tokens into Sequences of Integers

# %%
encoded_docs_train = vect.texts_to_sequences(x_train)
encoded_docs_test = vect.texts_to_sequences(x_test)
encoded_docs_val = vect.texts_to_sequences(x_val)

# %% [markdown]
# ### Padding and Making all the Sequences the same Length

# %%
# pad sequence
padded_docs_train = pad_sequences(encoded_docs_train, maxlen=max_len, padding="post")
padded_docs_test = pad_sequences(encoded_docs_test, maxlen=max_len, padding="post")
padded_docs_cv = pad_sequences(encoded_docs_val, maxlen=max_len, padding="post")

# %% [markdown]
# ### Find number of tokens in List

# %%
# add tokens in text column in a list 
# find number of tokens in list
review_lines = list()
lines = data["Text"].values.tolist()
for line in lines:
  tokens = word_tokenize(line)
  review_lines.append(tokens)

# %%
  len(review_lines)
# Out:
# 8815

# %% [markdown]
# ### Train Word2Vec model on the vocabulary

# %%
# sequence - list of tweets 
# size = size of vector/ dimension 
# min_count - words greater than mincount included in model
# workers - no of threads in training parallelisation 
model = gensim.models.Word2Vec(sentences=review_lines, size = EMBEDDING_DIM, window = 5, workers = 4, min_count=1)

# %%
words = list(model.wv.vocab)
print(words)
# Out:
# ['one', 'thing', 'love', 'life', 'mother', 'ever', 'come', 'mine', 'want', 'perfect', 'happy', 'mom', 'hates', 'dad', 'today', 'sucks', 'fword', 'tho', 'hate', 'feel', 'good', '“', 'single', 'tf', 'live', 'pappichulo', '2013', 'spoiled', 'believe', 'reality', 'i', 'blessed', '15factsaboutme', 'wish', 'could', 'go', 'back', 'ti', 'ame', 'change', 'best', 'year', '6', 'disappointment', 'memories', 'sword', 'must', 'say', '♡', 'make', 'suck', 'stop', 'every', 'mywishin2013', 'stay', 'way', 'better', 'last', 'someone', 'care', 'real', 'friends', 'dreams', 'true', 'everything', 'great', 'idk', 'quite', 'even', 'theres', 'ups', 'n', 'downs', 'flat', 'tired', 'sad', 'content', 'try', 'others', 'kid', 'like', 'someti', 'amesi', 'think', 'peoples', 'wonder', 'bring', 'nothing', 'blessing', 'chance', 'family', 'girl', 'thoughtsinthehallway', 'face', 'awesome', 'fabulous', 'loving', 'boy', 'np', 'middle', 'nowhere', 'dont', 'much', 'never', 'wanted', 'nothin', 'still', 'damn', 'amp', 'keeps', 'laughing', 'loud', 'need', 'keep', 'ha', 'course', 'bad', 'guy', 'shout', 'god', 'triple', 'wonderful', 'world', 'welcome', 'universe', 'bless', 'really', 'fine', '‚äæ', 'é∆™‚äæ', 'thanks', 'deserve', 'damnitstrue', 'listens', 'beautiful', 'laughs', 'absolutely', 'long', 'everyone', 'mission', 'failed', 'head', 'sigh', 'sighs', '\uf8ffüëå', '0', 'singing', 'ibi', 'e', 'dey', 'oo', 'smiles', 'around', 'honestly', 'watched', 'oh', 'alright', 'look', 'proud', 'wishes', 'aw', 'feeling', 'swear', 'would', '3', 'getting', 'done', 'wow', 'pathetic', 'noi', 'watching', 'awkward', 'either', 'horrible', 'memory', 'truly', 'matter', 'complicated', 'might', 'know', 'okay', 'end', 'happen', 'nods', 'tt', 'person', '100', 'can', 'not', 'complain', 'bro', 'sure', 'boyfriend', '16', 'left', 'mess', 'tweets', 'obviously', '2', 'freaking', '2012', 'made', 'worst', 'mistakes', 'people', 'words', 'bout', 'enjoying', 'get', 'lot', 'word', '500aday', 'embarrassing', '8', 'minutes', 'bar', '💁💋🍸', 'awful', 'yeaa', 'miserable', 'see', 'forever', 'period', 'liar', 'gone', 'blessedyes', 'sir', 'always', 'possibly', 'ugly', 'awh', 'stressed', 'sorry', 'reply', 'excitement', 'longer', 'camper', 'nah', 'complete', 'let', 'meant', 'woman', 'man', 'cant', 'decide', 'lmao', 'whole', 'lie', 'night', 'negative', 'cause', 'depressed', 'said', 'chappy', 'yaaa', 'mann', 'lls', 'mad', 'hard', 'ugh', 'story', 'lifeless', 'lord', 'living', 'friend', 'officialkhalittleu', 'p', 'pretty', 'weird', 'struggle', 'amare', 'please', 'x', 'wit', 'niggas', 'thang', 'enjoy', 'right', 'hea', 'yes', 'everyday', 'depressing', 'joke', 'accept', 'give', 'help', 'nope', 'working', 'kinda', 'ya', 'far…only', 'far', 'hey', 'point', 'thankful', 'class', 'cares', 'hell', 'lovearieee', 'home', 'boring', 'minute', 'kill', 'maybe', 'tomorrow', 'goes', 'badly', 'cuz', 'given', 'another', 'day', 'describe', 'die', 'failure', 'alcohol', 'else', 'ask', 'wtf', 'si', 'followed', 'luck', 'yeah', 'probably', 'gon', 'na', 'smile', 'almost', 'upset', 'irritated', 'leave', 'alone', 'turretbob', 'satisfied', 'already', 'got', 'u', 'tell', 'wbu', 'going', 'money', 'goin', 'school', 'yomillz', 'goal', 'call', 'sweet', 'follows', '1', 'lad', 'amazing', 'hear', 'thats', 'nice', 'fantastic', '´', 'dear', 'hope', 'realize', 'haha', 'hahaha', 'bearsmoke7', 'hehe', 'ikr', 'unhappy', 'bunny', 'talking', 'us', 'gf', 'lay', 'goddsgift', 'sick', 'machine', 'house', 'days', 'may', 'glass', 'numb', 'pain', 'swordty', 'l', 'jothysr', 'jujubear8', 'pflynne', 'meaning', 'lavadinhoashley', 'double', 'xoxo', '\uf8ffüíã', 'madi', 'extra', 'youthanks', 'giant', 'maguilar023', 'put', 'things', 'til', 'well', 'stupid', 'question', 'naya270', 'actually', 'decided', 'positive', 'rn', 'motherfworder', 'girlfriend', 'exhausted', 'hungry', 'found', 'xd', 'solbbestit', 'shall', 'commit', 'suicide', 'perfectly', 'cinderella', 'hbu', 'xsuprauhl', 'drama', 'free', 'study', 'ah', 'totally', 'ahahhaha', 'amin', 'ap', 'affirmation', 'coming', 'afraid', 'ice' ...

# %%
model.wv.most_similar('god')
# Out:
# [('thank', 0.9997314810752869),
#  ('blessing', 0.9997247457504272),
#  ('day', 0.9997138381004333),
#  ('much', 0.9996554851531982),
#  ('everyday', 0.9996306300163269),
#  ('things', 0.999629020690918),
#  ('na', 0.9996258020401001),
#  ('beautiful', 0.9996231198310852),
#  ('new', 0.9996185302734375),
#  ('way', 0.9996178150177002)]

# %%
# save model 
filename = '/content/gdrive/MyDrive/Depression Project/embedding_word2vec.txt'
model.wv.save_word2vec_format(filename, binary=False)

# %%
embedding_index = {}
f = open(os.path.join('', '/content/gdrive/MyDrive/Depression Project/embedding_word2vec.txt'), encoding = "utf-8")
for line in f:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:])
  embedding_index[word] = coefs
f.close()

# %% [markdown]
# ### Tokenize, Vectorize, turn it into sequence and Pad again

# %%
# vectorise tweets 
vect = Tokenizer()
vect.fit_on_texts(review_lines)
sequences = vect.texts_to_sequences(review_lines)

# %%
word_index = vect.word_index
print (len(word_index))
# Out:
# 1982

# %%
# pad sequence 
review_pad = pad_sequences(sequences, maxlen = max_len)
sentiment = data["Target"].values

# %%
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

for word, i in word_index.items():
  if i > num_words:
    continue
  embedding_vector = embedding_index.get(word)
  # words not found in embedding index will be 0 
  if embedding_vector is not None:
    embedding_matrix[i] = embedding_vector

# %%
print(num_words)
# Out:
# 1983

# %% [markdown]
# ### Build and compile DL Model

# %%
model = Sequential()
embedding_layer = Embedding(num_words, EMBEDDING_DIM, input_length= max_len, weights = [embedding_matrix])
# Configuring the parameters
model.add(embedding_layer)
model.add(layers.SimpleRNN(45))
model.add(Dropout(0.7))
# Adding a dense output layer with sigmoid activation
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 100)           198300
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 45)                6570
# _________________________________________________________________
# dropout (Dropout)            (None, 45)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 46
# =================================================================
# Total params: 204,916
# Trainable params: 204,916
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot NN model 
plot_model(model, to_file='/content/gdrive/MyDrive/Depression Project/mlp-mnist.png', show_shapes=True)

# %% [markdown]
# ### Split Validation Dataset

# %%
validation_split = 0.2 
indices = np.arange(review_pad.shape[0])
print(np.random.shuffle(indices))
review_pad = review_pad[indices]
sentiment = sentiment[indices]
num_validation_samples = int(validation_split * review_pad.shape[0])
print(num_validation_samples)
# Out:
# None
# 1763

# %%
padded_docs_train = review_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
padded_docs_cv = padded_docs_train[-num_validation_samples:]
y_val = y_train[-num_validation_samples:]
padded_docs_test = review_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(padded_docs_train, y_train,
                    epochs=50,
                    validation_data = (padded_docs_cv, y_val)
                    )
# Out:
# Epoch 1/50
# 221/221 [==============================] - 4s 10ms/step - loss: 0.6238 - accuracy: 0.6435 - val_loss: 0.2190 - val_accuracy: 0.9302
# Epoch 2/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.2178 - accuracy: 0.9248 - val_loss: 0.1551 - val_accuracy: 0.9467
# Epoch 3/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.1509 - accuracy: 0.9525 - val_loss: 0.1257 - val_accuracy: 0.9541
# Epoch 4/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.1340 - accuracy: 0.9552 - val_loss: 0.1044 - val_accuracy: 0.9654
# Epoch 5/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.1128 - accuracy: 0.9629 - val_loss: 0.0811 - val_accuracy: 0.9705
# Epoch 6/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.1037 - accuracy: 0.9659 - val_loss: 0.0761 - val_accuracy: 0.9705
# Epoch 7/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0967 - accuracy: 0.9707 - val_loss: 0.0617 - val_accuracy: 0.9784
# Epoch 8/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0812 - accuracy: 0.9719 - val_loss: 0.0775 - val_accuracy: 0.9671
# Epoch 9/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0777 - accuracy: 0.9721 - val_loss: 0.0552 - val_accuracy: 0.9790
# Epoch 10/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0617 - accuracy: 0.9784 - val_loss: 0.0595 - val_accuracy: 0.9784
# Epoch 11/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0760 - accuracy: 0.9726 - val_loss: 0.0517 - val_accuracy: 0.9824
# Epoch 12/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0773 - accuracy: 0.9711 - val_loss: 0.0636 - val_accuracy: 0.9739
# Epoch 13/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0655 - accuracy: 0.9749 - val_loss: 0.0660 - val_accuracy: 0.9767
# Epoch 14/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0670 - accuracy: 0.9783 - val_loss: 0.0465 - val_accuracy: 0.9841
# Epoch 15/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0701 - accuracy: 0.9766 - val_loss: 0.0451 - val_accuracy: 0.9830
# Epoch 16/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0711 - accuracy: 0.9754 - val_loss: 0.0635 - val_accuracy: 0.9773
# Epoch 17/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0808 - accuracy: 0.9713 - val_loss: 0.0557 - val_accuracy: 0.9796
# Epoch 18/50
# 221/221 [==============================] - 2s 7ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 0.0460 - val_accuracy: 0.9853
# Epoch 19/50
# 221/221 [==============================] - 2s 7ms/step - loss: 0.0600 - accuracy: 0.9795 - val_loss: 0.0440 - val_accuracy: 0.9864
# Epoch 20/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0653 - accuracy: 0.9785 - val_loss: 0.0427 - val_accuracy: 0.9853
# Epoch 21/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0581 - accuracy: 0.9805 - val_loss: 0.0494 - val_accuracy: 0.9813
# Epoch 22/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0569 - accuracy: 0.9802 - val_loss: 0.0514 - val_accuracy: 0.9824
# Epoch 23/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0691 - accuracy: 0.9755 - val_loss: 0.0467 - val_accuracy: 0.9836
# Epoch 24/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0607 - accuracy: 0.9777 - val_loss: 0.0433 - val_accuracy: 0.9830
# Epoch 25/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0585 - accuracy: 0.9775 - val_loss: 0.0536 - val_accuracy: 0.9841
# Epoch 26/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0608 - accuracy: 0.9816 - val_loss: 0.0423 - val_accuracy: 0.9847
# Epoch 27/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0536 - accuracy: 0.9802 - val_loss: 0.0415 - val_accuracy: 0.9830
# Epoch 28/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0545 - accuracy: 0.9812 - val_loss: 0.0418 - val_accuracy: 0.9864
# Epoch 29/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0656 - accuracy: 0.9788 - val_loss: 0.0384 - val_accuracy: 0.9841
# Epoch 30/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0640 - accuracy: 0.9759 - val_loss: 0.0393 - val_accuracy: 0.9847
# Epoch 31/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0567 - accuracy: 0.9792 - val_loss: 0.0459 - val_accuracy: 0.9841
# Epoch 32/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0587 - accuracy: 0.9796 - val_loss: 0.0384 - val_accuracy: 0.9858
# Epoch 33/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0501 - accuracy: 0.9839 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 34/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0535 - accuracy: 0.9814 - val_loss: 0.0363 - val_accuracy: 0.9864
# Epoch 35/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0479 - accuracy: 0.9844 - val_loss: 0.0400 - val_accuracy: 0.9864
# Epoch 36/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0608 - accuracy: 0.9767 - val_loss: 0.0385 - val_accuracy: 0.9853
# Epoch 37/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0552 - accuracy: 0.9799 - val_loss: 0.0415 - val_accuracy: 0.9858
# Epoch 38/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0561 - accuracy: 0.9808 - val_loss: 0.0418 - val_accuracy: 0.9853
# Epoch 39/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0472 - accuracy: 0.9845 - val_loss: 0.0355 - val_accuracy: 0.9875
# Epoch 40/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0605 - accuracy: 0.9779 - val_loss: 0.0374 - val_accuracy: 0.9870
# Epoch 41/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0590 - accuracy: 0.9804 - val_loss: 0.0364 - val_accuracy: 0.9870
# Epoch 42/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0494 - accuracy: 0.9838 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 43/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0505 - accuracy: 0.9822 - val_loss: 0.0472 - val_accuracy: 0.9836
# Epoch 44/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0752 - accuracy: 0.9743 - val_loss: 0.0384 - val_accuracy: 0.9881
# Epoch 45/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0562 - accuracy: 0.9787 - val_loss: 0.0388 - val_accuracy: 0.9864
# Epoch 46/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0504 - accuracy: 0.9823 - val_loss: 0.0367 - val_accuracy: 0.9881
# Epoch 47/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0535 - accuracy: 0.9805 - val_loss: 0.0401 - val_accuracy: 0.9864
# Epoch 48/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0516 - accuracy: 0.9812 - val_loss: 0.0396 - val_accuracy: 0.9864
# Epoch 49/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0570 - accuracy: 0.9798 - val_loss: 0.0342 - val_accuracy: 0.9875
# Epoch 50/50
# 221/221 [==============================] - 2s 8ms/step - loss: 0.0460 - accuracy: 0.9834 - val_loss: 0.0412 - val_accuracy: 0.9836

# %% [markdown]
# ### Evaluate the Model

# %%
model.evaluate(padded_docs_test, y_test)
# Out:
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.9053
# [0.38439568877220154, 0.9052751064300537]

# %%
x_test.head()
# Out:
#             Id                            Text  Target
# 2143   2.9e+17                     social life       0
# 2181   2.9e+17                    good friends       1
# 4425  2.85e+17  listening love cause hate life       0
# 2577   2.9e+17           love never gets bored       1
# 2213   2.9e+17             best boyfriend ever       1

# %%
pred = model.predict_classes(padded_docs_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
text = x_test["Text"]
#pred = np.argmax(pred, axis = 1)

# %%
for i in range(1763):
  print("Text: ",x_test["Text"].iloc[i], "-->", "Actual Label: ", x_test["Target"].iloc[i], "-->", "Predicted: ", pred[i])
# Out:
# Text:  social life --> Actual Label:  0 --> Predicted:  [1]
# Text:  good friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  listening love cause hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  love never gets bored --> Actual Label:  1 --> Predicted:  [0]
# Text:  best boyfriend ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  wow suck --> Actual Label:  0 --> Predicted:  [0]
# Text:  life series unfounate fworded events --> Actual Label:  0 --> Predicted:  [1]
# Text:  god bless --> Actual Label:  1 --> Predicted:  [0]
# Text:  yes i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i ame life i loving every single moment --> Actual Label:  1 --> Predicted:  [1]
# Text:  i feeling great --> Actual Label:  1 --> Predicted:  [0]
# Text:  i made like worst mistakes ever --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  new resolution drink life fword terrible --> Actual Label:  0 --> Predicted:  [1]
# Text:  love looking --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel like proud parent --> Actual Label:  1 --> Predicted:  [0]
# Text:  love --> Actual Label:  1 --> Predicted:  [0]
# Text:  goals life --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword sword fword life hate fword dad fword --> Actual Label:  0 --> Predicted:  [0]
# Text:  i never many emotional days life good --> Actual Label:  1 --> Predicted:  [0]
# Text:  little bit still love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  good thanks asking --> Actual Label:  1 --> Predicted:  [0]
# Text:  want --> Actual Label:  1 --> Predicted:  [1]
# Text:  may get want get need i satisfied go outsearch constant new --> Actual Label:  1 --> Predicted:  [0]
# Text:  blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  really happy going well though --> Actual Label:  1 --> Predicted:  [0]
# Text:  want alone miserable life u wanna make fun i fully aware existence --> Actual Label:  0 --> Predicted:  [0]
# Text:  enjoy life yeah --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  stressed could --> Actual Label:  0 --> Predicted:  [0]
# Text:  like i proud --> Actual Label:  1 --> Predicted:  [1]
# Text:  wtf wtf wtf yes yes yes happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  wow love happy laughing loud --> Actual Label:  1 --> Predicted:  [0]
# Text:  i really unhappy try --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  best friends ever haha --> Actual Label:  1 --> Predicted:  [1]
# Text:  wishes come true --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life matter good bad know god always enough --> Actual Label:  1 --> Predicted:  [0]
# Text:  allah thank giving happiness friends well need happiness --> Actual Label:  1 --> Predicted:  [0]
# Text:  one proud friend --> Actual Label:  1 --> Predicted:  [1]
# Text:  get want --> Actual Label:  1 --> Predicted:  [0]
# Text:  i never sick life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate feel alone --> Actual Label:  0 --> Predicted:  [1]
# Text:  i far perfect --> Actual Label:  0 --> Predicted:  [1]
# Text:  “ tripping life great --> Actual Label:  1 --> Predicted:  [0]
# Text:  really fast love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  bestest friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  i sorry suck --> Actual Label:  0 --> Predicted:  [1]
# Text:  i love --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bad girl3 --> Actual Label:  0 --> Predicted:  [0]
# Text:  want friends want happy want fulfill die --> Actual Label:  0 --> Predicted:  [1]
# Text:  nope i amazing --> Actual Label:  1 --> Predicted:  [1]
# Text:  miss happy little kid --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  ah life totally complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  i actually sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  life complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  damn love --> Actual Label:  1 --> Predicted:  [1]
# Text:  worst back problems --> Actual Label:  0 --> Predicted:  [0]
# Text:  oh even describe beautiful life --> Actual Label:  1 --> Predicted:  [1]
# Text:  lool nah i proud --> Actual Label:  1 --> Predicted:  [1]
# Text:  naw naw i good boy laughing loud --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good ready i shall i ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate embarrassing 😒 --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  going make new years resolution i happy life way --> Actual Label:  1 --> Predicted:  [1]
# Text:  yay life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  really good real friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  honestly think worst luck tho --> Actual Label:  0 --> Predicted:  [0]
# Text:  want die right --> Actual Label:  0 --> Predicted:  [0]
# Text:  i got pocket full sunshine --> Actual Label:  1 --> Predicted:  [1]
# Text:  millipede amazing --> Actual Label:  1 --> Predicted:  [1]
# Text:  yes i good boy haha --> Actual Label:  1 --> Predicted:  [0]
# Text:  oh god i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  love --> Actual Label:  1 --> Predicted:  [0]
# Text:  like living kinda lifei living blessed life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sick always feeling sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  feel fine feel good --> Actual Label:  1 --> Predicted:  [0]
# Text:  amazing everything need life complete happy blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  best best friend ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  suppose act happy i --> Actual Label:  0 --> Predicted:  [1]
# Text:  want happy use --> Actual Label:  0 --> Predicted:  [0]
# Text:  thank god waking blessing --> Actual Label:  1 --> Predicted:  [1]
# Text:  never happy fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  stressed depressed lets face i mess --> Actual Label:  0 --> Predicted:  [0]
# Text:  always get want eventually --> Actual Label:  1 --> Predicted:  [1]
# Text:  like living life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i asshole i proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  disgusted ugh --> Actual Label:  0 --> Predicted:  [0]
# Text:  “ good friend --> Actual Label:  1 --> Predicted:  [0]
# Text:  literally fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  woke breathing alive i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  life getting boring ha ha ha --> Actual Label:  0 --> Predicted:  [0]
# Text:  da best --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel disappointment --> Actual Label:  0 --> Predicted:  [1]
# Text:  i finally found love life ti ame --> Actual Label:  1 --> Predicted:  [0]
# Text:  excited getting life --> Actual Label:  0 --> Predicted:  [0]
# Text:  life😂😒😔 --> Actual Label:  0 --> Predicted:  [0]
# Text:  sad like wow --> Actual Label:  0 --> Predicted:  [0]
# Text:  stupid --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never felt sick whole life --> Actual Label:  0 --> Predicted:  [0]
# Text:  blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword smh --> Actual Label:  0 --> Predicted:  [1]
# Text:  depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  soo need change life --> Actual Label:  0 --> Predicted:  [1]
# Text:  love good --> Actual Label:  1 --> Predicted:  [1]
# Text:  oh life get comfoable --> Actual Label:  0 --> Predicted:  [1]
# Text:  one proud motherfworder --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  ew feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  laughing loud fword hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  cannot possible i amagine exactly much hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  sad sad life --> Actual Label:  0 --> Predicted:  [1]
# Text:  raldo i grown want --> Actual Label:  1 --> Predicted:  [0]
# Text:  2012 best year lifeso far --> Actual Label:  1 --> Predicted:  [1]
# Text:  soundtrack life probably best rap ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  i lucky i blessedyes --> Actual Label:  1 --> Predicted:  [1]
# Text:  worst attitude problems --> Actual Label:  0 --> Predicted:  [0]
# Text:  life much wanna leave world person cares dnt need u get pappaer bitch --> Actual Label:  0 --> Predicted:  [0]
# Text:  enjoying life --> Actual Label:  1 --> Predicted:  [1]
# Text:  seriously need better social life --> Actual Label:  0 --> Predicted:  [1]
# Text:  never life felt pain like --> Actual Label:  0 --> Predicted:  [1]
# Text:  everything need --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate sister hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  get ruined happiness fworden ruin best friends happiness stupid slut --> Actual Label:  0 --> Predicted:  [0]
# Text:  sorry i disappointment --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate knowing wohless --> Actual Label:  0 --> Predicted:  [1]
# Text:  i --> Actual Label:  1 --> Predicted:  [0]
# Text:  best big sister 😎 --> Actual Label:  1 --> Predicted:  [1]
# Text:  believe i living good life though face situation i living --> Actual Label:  1 --> Predicted:  [1]
# Text:  i --> Actual Label:  1 --> Predicted:  [1]
# Text:  life great i living --> Actual Label:  1 --> Predicted:  [1]
# Text:  life boring like --> Actual Label:  0 --> Predicted:  [1]
# Text:  listens i best --> Actual Label:  1 --> Predicted:  [1]
# Text:  body happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  realized life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  life sword --> Actual Label:  0 --> Predicted:  [1]
# Text:  life --> Actual Label:  0 --> Predicted:  [0]
# Text:  true life --> Actual Label:  1 --> Predicted:  [0]
# Text:  good influence --> Actual Label:  1 --> Predicted:  [0]
# Text:  wow i soo happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  always get wat want --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  hey i love --> Actual Label:  1 --> Predicted:  [1]
# Text:  need change life --> Actual Label:  0 --> Predicted:  [0]
# Text:  feel bad man --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  know nothing failure need alcohol --> Actual Label:  0 --> Predicted:  [0]
# Text:  sad help --> Actual Label:  0 --> Predicted:  [1]
# Text:  haha i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i super happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  life wrong --> Actual Label:  0 --> Predicted:  [1]
# Text:  bitch i fabulous --> Actual Label:  1 --> Predicted:  [0]
# Text:  actually pretty good --> Actual Label:  1 --> Predicted:  [1]
# Text:  ahahah love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i love --> Actual Label:  1 --> Predicted:  [1]
# Text:  honestly appreciate everything everyone life --> Actual Label:  1 --> Predicted:  [0]
# Text:  best boyfriend things females tweet good dick --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  know happy hahaha --> Actual Label:  1 --> Predicted:  [1]
# Text:  may perfect least i happy life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good --> Actual Label:  0 --> Predicted:  [0]
# Text:  i proud myselfthat soupmy god --> Actual Label:  1 --> Predicted:  [0]
# Text:  one happy gal --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like bad guy --> Actual Label:  0 --> Predicted:  [0]
# Text:  love people life want people --> Actual Label:  1 --> Predicted:  [0]
# Text:  lovearieee i sad sad i sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  i happy girl --> Actual Label:  1 --> Predicted:  [0]
# Text:  i need damn change --> Actual Label:  0 --> Predicted:  [0]
# Text:  god blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  damn life laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  life pathetic --> Actual Label:  0 --> Predicted:  [0]
# Text:  want tell world happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life made --> Actual Label:  1 --> Predicted:  [0]
# Text:  friendshlp want live life without stress worries need rich famous want happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  pay good ti ame --> Actual Label:  1 --> Predicted:  [1]
# Text:  next normal close still sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  life made --> Actual Label:  1 --> Predicted:  [1]
# Text:  amazing cannot believe life swordfest --> Actual Label:  0 --> Predicted:  [0]
# Text:  dead fword bad man --> Actual Label:  0 --> Predicted:  [1]
# Text:  ah fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  damn right love life live --> Actual Label:  1 --> Predicted:  [0]
# Text:  dreams coming true --> Actual Label:  1 --> Predicted:  [1]
# Text:  another love haha --> Actual Label:  1 --> Predicted:  [0]
# Text:  like ti ames --> Actual Label:  1 --> Predicted:  [0]
# Text:  i reason hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  yes i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  joselineee16 depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword i bored friends boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  mariakastani cannot ever happy person --> Actual Label:  0 --> Predicted:  [1]
# Text:  life --> Actual Label:  1 --> Predicted:  [1]
# Text:  want die --> Actual Label:  0 --> Predicted:  [0]
# Text:  i point life much could complain i happy got --> Actual Label:  1 --> Predicted:  [1]
# Text:  “ never happy” --> Actual Label:  0 --> Predicted:  [0]
# Text:  really fword hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  eh i huing really bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy i shaking --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  ´ i always happy dear hope u --> Actual Label:  1 --> Predicted:  [1]
# Text:  nothing phone cause talk one sad life mine --> Actual Label:  0 --> Predicted:  [0]
# Text:  need --> Actual Label:  1 --> Predicted:  [0]
# Text:  like life live --> Actual Label:  1 --> Predicted:  [0]
# Text:  always say i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  get good feeling yeah --> Actual Label:  1 --> Predicted:  [1]
# Text:  suck --> Actual Label:  0 --> Predicted:  [1]
# Text:  dream come true --> Actual Label:  1 --> Predicted:  [1]
# Text:  i sick life want sta somewhere new --> Actual Label:  0 --> Predicted:  [0]
# Text:  i lucky i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  rather good assets --> Actual Label:  1 --> Predicted:  [1]
# Text:  nothing planned --> Actual Label:  0 --> Predicted:  [0]
# Text:  keep bad girl side --> Actual Label:  0 --> Predicted:  [0]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [0]
# Text:  gone forever fword life --> Actual Label:  0 --> Predicted:  [0]
# Text:  fword life doe --> Actual Label:  0 --> Predicted:  [0]
# Text:  i great --> Actual Label:  1 --> Predicted:  [0]
# Text:  story life sweet pea --> Actual Label:  1 --> Predicted:  [0]
# Text:  think i ever disappointed entire life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sick 😔 --> Actual Label:  0 --> Predicted:  [1]
# Text:  want fword cry eyes going home hate life everything --> Actual Label:  0 --> Predicted:  [0]
# Text:  life awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  laughing loud i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate putting mood --> Actual Label:  0 --> Predicted:  [0]
# Text:  i’m good human --> Actual Label:  1 --> Predicted:  [1]
# Text:  thank god everything --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life bye twitter --> Actual Label:  0 --> Predicted:  [1]
# Text:  i i would say i pretty happy blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  never ever sick life --> Actual Label:  0 --> Predicted:  [1]
# Text:  dreams come true amin 4 --> Actual Label:  1 --> Predicted:  [1]
# Text:  life totally happy right noww --> Actual Label:  1 --> Predicted:  [0]
# Text:  sigh love life sucks even --> Actual Label:  0 --> Predicted:  [1]
# Text:  i pretty good --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life right noww --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel depressed empty way feel depressed way feel anything --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate hate life hate everything --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  content wit evehaaaaang life --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life everybody --> Actual Label:  1 --> Predicted:  [0]
# Text:  best friend x --> Actual Label:  1 --> Predicted:  [0]
# Text:  damn i soo blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  2013 want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  always get want --> Actual Label:  1 --> Predicted:  [0]
# Text:  know look good --> Actual Label:  1 --> Predicted:  [0]
# Text:  must say enjoying --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  blessed highly favored --> Actual Label:  1 --> Predicted:  [0]
# Text:  i blessed god says --> Actual Label:  1 --> Predicted:  [0]
# Text:  life dawg --> Actual Label:  0 --> Predicted:  [1]
# Text:  perfect --> Actual Label:  1 --> Predicted:  [1]
# Text:  i sorry i bad boy laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  best boyfriend ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  almost everything going planned i pleased --> Actual Label:  1 --> Predicted:  [0]
# Text:  love jesus always --> Actual Label:  1 --> Predicted:  [0]
# Text:  fell top world --> Actual Label:  1 --> Predicted:  [0]
# Text:  hi name sarah life joke --> Actual Label:  0 --> Predicted:  [1]
# Text:  love --> Actual Label:  1 --> Predicted:  [1]
# Text:  jayz4dayz i happy life complaints pain --> Actual Label:  1 --> Predicted:  [1]
# Text:  life seriously fworded --> Actual Label:  0 --> Predicted:  [0]
# Text:  literally hate much --> Actual Label:  0 --> Predicted:  [1]
# Text:  i really always happy person --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  life sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  yup best --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life fworded get --> Actual Label:  0 --> Predicted:  [0]
# Text:  met amazing people life --> Actual Label:  1 --> Predicted:  [0]
# Text:  reievantquotes thank god blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy i --> Actual Label:  1 --> Predicted:  [1]
# Text:  god fword hate crying sleep --> Actual Label:  0 --> Predicted:  [0]
# Text:  awesome --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword life fword good --> Actual Label:  0 --> Predicted:  [1]
# Text:  really life --> Actual Label:  0 --> Predicted:  [0]
# Text:  thankin god blessing like crazy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  cares boring life --> Actual Label:  0 --> Predicted:  [0]
# Text:  want curl ball die literally --> Actual Label:  0 --> Predicted:  [0]
# Text:  life boring laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  stamp sword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  someone hear cry i dying new life --> Actual Label:  0 --> Predicted:  [0]
# Text:  life thx asking --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel like whole life joke --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i never actually drugs i happy ti ame --> Actual Label:  1 --> Predicted:  [0]
# Text:  i done feeling disgusting --> Actual Label:  0 --> Predicted:  [0]
# Text:  ahahaha nah i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  good girl sobs --> Actual Label:  1 --> Predicted:  [0]
# Text:  swear hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel good --> Actual Label:  1 --> Predicted:  [0]
# Text:  i still love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good mood --> Actual Label:  1 --> Predicted:  [1]
# Text:  sucks 100 positive death bed better sta --> Actual Label:  0 --> Predicted:  [1]
# Text:  good one proud girl --> Actual Label:  1 --> Predicted:  [0]
# Text:  i blessed tho --> Actual Label:  1 --> Predicted:  [1]
# Text:  good ass friends man --> Actual Label:  1 --> Predicted:  [1]
# Text:  “ take good care 💅💆👑👌 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i thinking clearly know want --> Actual Label:  1 --> Predicted:  [0]
# Text:  smile watching cinderella story life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  oh god hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  best coworkers ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sad alone sad sad alone sadalone sa sa hi i alone sad sad alone --> Actual Label:  0 --> Predicted:  [0]
# Text:  life complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  merp life --> Actual Label:  0 --> Predicted:  [0]
# Text:  man feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  i dying boredom --> Actual Label:  0 --> Predicted:  [0]
# Text:  life sucks i becoming bye --> Actual Label:  0 --> Predicted:  [1]
# Text:  i best --> Actual Label:  1 --> Predicted:  [1]
# Text:  lord dont feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  always content happens know god better choose --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life sound like freaking retard like uhm --> Actual Label:  0 --> Predicted:  [0]
# Text:  i soooo happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  blessed blessed everyday life blessed wake morning --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  worst guy ever --> Actual Label:  0 --> Predicted:  [0]
# Text:  life fworded honest --> Actual Label:  0 --> Predicted:  [1]
# Text:  want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  single want tf --> Actual Label:  1 --> Predicted:  [1]
# Text:  need nobody else --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bad boy --> Actual Label:  0 --> Predicted:  [0]
# Text:  realized happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  see sad life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never felt disgusting life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i worst --> Actual Label:  0 --> Predicted:  [0]
# Text:  life perfect i thankful --> Actual Label:  1 --> Predicted:  [1]
# Text:  get want --> Actual Label:  1 --> Predicted:  [1]
# Text:  things calm get never truly satisfied happy saddest lie --> Actual Label:  0 --> Predicted:  [0]
# Text:  i got nothing --> Actual Label:  0 --> Predicted:  [1]
# Text:  omfg favourited life complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  god damn i awful --> Actual Label:  0 --> Predicted:  [0]
# Text:  wait actually hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  i --> Actual Label:  1 --> Predicted:  [0]
# Text:  ask god i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [0]
# Text:  story life left terrible --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate feeling depression --> Actual Label:  0 --> Predicted:  [1]
# Text:  i disappointed man --> Actual Label:  0 --> Predicted:  [0]
# Text:  honestly feel terrible ti ame --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy point ti ame life --> Actual Label:  1 --> Predicted:  [0]
# Text:  na nai good --> Actual Label:  1 --> Predicted:  [1]
# Text:  may perfect least i happy life --> Actual Label:  1 --> Predicted:  [0]
# Text:  best big brothers ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life 3 --> Actual Label:  1 --> Predicted:  [1]
# Text:  god stays know i blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  i disappointment --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  like suck life --> Actual Label:  0 --> Predicted:  [0]
# Text:  dont think ive ever played bad life --> Actual Label:  0 --> Predicted:  [0]
# Text:  life great --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  life sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel like i top world love --> Actual Label:  1 --> Predicted:  [0]
# Text:  right stressed --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate fword teenage life --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life guy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i proud cannot explain i --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate late --> Actual Label:  0 --> Predicted:  [0]
# Text:  bestest friends ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  best friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  life never felt complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  bunny kid melted melted life awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  made many stupid decisions life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i still happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  thank god blessing another day --> Actual Label:  1 --> Predicted:  [1]
# Text:  i glad achieved ai --> Actual Label:  1 --> Predicted:  [0]
# Text:  love find everything --> Actual Label:  1 --> Predicted:  [0]
# Text:  sick fword life --> Actual Label:  0 --> Predicted:  [0]
# Text:  think made worst mistake life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword fword loving --> Actual Label:  1 --> Predicted:  [0]
# Text:  incredibly blessed thankful everyone life god great i i would lost without hi --> Actual Label:  1 --> Predicted:  [0]
# Text:  ti ames like get think wish life different --> Actual Label:  0 --> Predicted:  [0]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  i really happy girl --> Actual Label:  1 --> Predicted:  [0]
# Text:  i none --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bloody brilliant --> Actual Label:  1 --> Predicted:  [1]
# Text:  jus want one thing happy much ask --> Actual Label:  0 --> Predicted:  [0]
# Text:  laughing loud know life lame --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  life way good true --> Actual Label:  1 --> Predicted:  [1]
# Text:  whole life fword lie --> Actual Label:  0 --> Predicted:  [0]
# Text:  nothing failure always always constantly let everyone never make anyone happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  wrong life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i real good mood --> Actual Label:  1 --> Predicted:  [0]
# Text:  frhjsmne mywishin2013 want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  still feeling sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  use fast forward swordty life --> Actual Label:  0 --> Predicted:  [0]
# Text:  alot friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  life pretty boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  ew hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  got fired ft job 2 days ago readveised miss friends life sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life great yea ups downs great friends family woh end --> Actual Label:  1 --> Predicted:  [1]
# Text:  loving good wife --> Actual Label:  1 --> Predicted:  [0]
# Text:  oh feel good --> Actual Label:  1 --> Predicted:  [1]
# Text:  dang i super sad byestl --> Actual Label:  0 --> Predicted:  [1]
# Text:  i happy life --> Actual Label:  1 --> Predicted:  [1]
# Text:  mywishin2013 happy want --> Actual Label:  0 --> Predicted:  [0]
# Text:  fword life man --> Actual Label:  0 --> Predicted:  [1]
# Text:  seriously worst mood swings ever one minute i like next i like soemotional hatemylife --> Actual Label:  0 --> Predicted:  [1]
# Text:  haha i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  always one thing another i tired unhappy --> Actual Label:  0 --> Predicted:  [1]
# Text:  sitting around cause life --> Actual Label:  0 --> Predicted:  [0]
# Text:  sorry i fword --> Actual Label:  0 --> Predicted:  [1]
# Text:  making life living hell --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear weirdest sword happens --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life everything sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  i horrible person --> Actual Label:  0 --> Predicted:  [0]
# Text:  i truly blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  whatever want --> Actual Label:  1 --> Predicted:  [0]
# Text:  i afraid losing long give ti ame try i fine --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy happy together happy 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy though lifes good --> Actual Label:  1 --> Predicted:  [0]
# Text:  ey ey uu stupid brother --> Actual Label:  0 --> Predicted:  [1]
# Text:  say happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  jaredfoxx happy saddest lie --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [1]
# Text:  i truly blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  cause i perfect --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love clothes love love love --> Actual Label:  1 --> Predicted:  [1]
# Text:  sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  ‚äú i --> Actual Label:  1 --> Predicted:  [0]
# Text:  really truly hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  hahahah life sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  new changes life i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  life dream --> Actual Label:  1 --> Predicted:  [0]
# Text:  thank lord giving good life live appreciated always --> Actual Label:  1 --> Predicted:  [1]
# Text:  good boy p --> Actual Label:  1 --> Predicted:  [1]
# Text:  i totally love mine 3 amazing --> Actual Label:  1 --> Predicted:  [0]
# Text:  everything hus want die --> Actual Label:  0 --> Predicted:  [0]
# Text:  i beautiful --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life point would change nothin --> Actual Label:  1 --> Predicted:  [1]
# Text:  i beyond blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy person know --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword life max --> Actual Label:  0 --> Predicted:  [1]
# Text:  yeah laughing loud worst headache --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  500aday hate embarrassing --> Actual Label:  0 --> Predicted:  [1]
# Text:  worst headache everrr😭 --> Actual Label:  0 --> Predicted:  [1]
# Text:  life becoming boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  life hard sho need drink --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life though --> Actual Label:  1 --> Predicted:  [0]
# Text:  know i singing i happy i happy soso happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  get depressed everyday --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel bad okay man --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  i thankful life thank god love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i depressed ass oh god i depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy u dont even know --> Actual Label:  1 --> Predicted:  [1]
# Text:  single life boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  best play tho --> Actual Label:  1 --> Predicted:  [0]
# Text:  ha ha love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  best friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  everyone ti ame hate life ti ame never goes away ever --> Actual Label:  0 --> Predicted:  [1]
# Text:  girlsposts happy prefer --> Actual Label:  1 --> Predicted:  [1]
# Text:  i single happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life never ending sick joke --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  everyday wonderful day wake live life knowing best family friends 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i worry wa hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  life i loving living --> Actual Label:  1 --> Predicted:  [0]
# Text:  everything like depressing bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  smile i blessed 💙 life --> Actual Label:  1 --> Predicted:  [0]
# Text:  life awkward moments --> Actual Label:  0 --> Predicted:  [0]
# Text:  i nothing huing --> Actual Label:  0 --> Predicted:  [0]
# Text:  head i good life --> Actual Label:  1 --> Predicted:  [1]
# Text:  guys i love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i accepted i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  blessed stressed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i great --> Actual Label:  1 --> Predicted:  [0]
# Text:  boring life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good man --> Actual Label:  1 --> Predicted:  [1]
# Text:  i bad person --> Actual Label:  0 --> Predicted:  [0]
# Text:  fun --> Actual Label:  1 --> Predicted:  [1]
# Text:  i unhappy --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sure fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  i i proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  life soooo --> Actual Label:  0 --> Predicted:  [1]
# Text:  terrible person --> Actual Label:  0 --> Predicted:  [0]
# Text:  believe worst i ammune system ever --> Actual Label:  0 --> Predicted:  [1]
# Text:  tired much sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy say everything could possibly want life would change thing --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  love haha --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like disappointment --> Actual Label:  0 --> Predicted:  [1]
# Text:  i really good --> Actual Label:  1 --> Predicted:  [0]
# Text:  buy anything want cuz got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  buy anything want cuz got check --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good u --> Actual Label:  1 --> Predicted:  [1]
# Text:  someti ames want able feel happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  boy really hate everything way look laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  buy anything want got check --> Actual Label:  1 --> Predicted:  [0]
# Text:  ever hate hate everyday --> Actual Label:  0 --> Predicted:  [1]
# Text:  count every day blessing case i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life mom --> Actual Label:  0 --> Predicted:  [0]
# Text:  fword whole life tell --> Actual Label:  0 --> Predicted:  [0]
# Text:  life laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  love good --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel good üëéüòû --> Actual Label:  0 --> Predicted:  [0]
# Text:  i n love --> Actual Label:  1 --> Predicted:  [1]
# Text:  love way --> Actual Label:  1 --> Predicted:  [1]
# Text:  really hate life ugh 😡 😡 --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  god continues bless --> Actual Label:  1 --> Predicted:  [0]
# Text:  jesus love --> Actual Label:  1 --> Predicted:  [0]
# Text:  would change thing --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life love even hours 5 --> Actual Label:  1 --> Predicted:  [0]
# Text:  woman 😉 --> Actual Label:  1 --> Predicted:  [1]
# Text:  probably knows i bad boy --> Actual Label:  0 --> Predicted:  [0]
# Text:  best sisters ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  sup i beautiful --> Actual Label:  1 --> Predicted:  [0]
# Text:  god blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  bc i moment i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  glad real friends lmao --> Actual Label:  1 --> Predicted:  [0]
# Text:  yep i miserable --> Actual Label:  0 --> Predicted:  [0]
# Text:  i angry sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  swear stressed life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i definitely good --> Actual Label:  0 --> Predicted:  [1]
# Text:  i one good --> Actual Label:  1 --> Predicted:  [1]
# Text:  i bit sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i breathing ✔ i alive ✔ i blessed ✔ amen --> Actual Label:  1 --> Predicted:  [1]
# Text:  love content happyhappyhappy --> Actual Label:  1 --> Predicted:  [0]
# Text:  hahaha yeah oh god i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  anything want cause got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love üòç --> Actual Label:  1 --> Predicted:  [1]
# Text:  life boring feel 100 years old --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  tvd life love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i beautiful 3 --> Actual Label:  1 --> Predicted:  [1]
# Text:  yeah got life --> Actual Label:  0 --> Predicted:  [1]
# Text:  idk maybe i depressed person --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  want fun life --> Actual Label:  1 --> Predicted:  [0]
# Text:  god words cannot describe much love thanks blessing life everything --> Actual Label:  1 --> Predicted:  [1]
# Text:  great life --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  think i depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword always sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  man living good life --> Actual Label:  1 --> Predicted:  [0]
# Text:  hus knowing i shall i never happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  srsly life boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  honestly someone trade i sick swordty life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate sensitive emotional --> Actual Label:  0 --> Predicted:  [1]
# Text:  anything want get --> Actual Label:  1 --> Predicted:  [0]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  made pissing idk man life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate life bye --> Actual Label:  0 --> Predicted:  [1]
# Text:  si p happy day --> Actual Label:  1 --> Predicted:  [1]
# Text:  made feel proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  got dreams got --> Actual Label:  1 --> Predicted:  [0]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  life good nowadays --> Actual Label:  1 --> Predicted:  [1]
# Text:  keeping emotions honestly best thing i done life i i would say i perfect --> Actual Label:  1 --> Predicted:  [0]
# Text:  damnitstrue thanks god blessing deserve --> Actual Label:  1 --> Predicted:  [1]
# Text:  life live pretty --> Actual Label:  1 --> Predicted:  [0]
# Text:  love love love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  good news --> Actual Label:  1 --> Predicted:  [0]
# Text:  supposed happy i surrounded --> Actual Label:  0 --> Predicted:  [1]
# Text:  yes i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  got sword goin life --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life matter complicated might know everything okay end --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love --> Actual Label:  1 --> Predicted:  [0]
# Text:  let us say i terrible person --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword life dude omfg --> Actual Label:  0 --> Predicted:  [0]
# Text:  pocket full sunshine --> Actual Label:  1 --> Predicted:  [1]
# Text:  i makes best --> Actual Label:  1 --> Predicted:  [1]
# Text:  mywishin2013 happy life happy kid like --> Actual Label:  1 --> Predicted:  [0]
# Text:  sorry i bad person --> Actual Label:  0 --> Predicted:  [0]
# Text:  i good mood --> Actual Label:  1 --> Predicted:  [1]
# Text:  lmfaoo life awesome tglicks lmfao oh god made laugh --> Actual Label:  1 --> Predicted:  [1]
# Text:  i much fun --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i also good --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  getting hu life --> Actual Label:  0 --> Predicted:  [1]
# Text:  things like --> Actual Label:  1 --> Predicted:  [0]
# Text:  uh kinda love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  ohmigod ohmigod love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  long god everything need --> Actual Label:  1 --> Predicted:  [0]
# Text:  jk actually life --> Actual Label:  0 --> Predicted:  [0]
# Text:  seriously hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  watch dreams come true --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good person hate --> Actual Label:  1 --> Predicted:  [1]
# Text:  life happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  oh god found love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i always love --> Actual Label:  1 --> Predicted:  [1]
# Text:  another great morning ahh love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  thank god every blessing death love everything everything live learn everyday --> Actual Label:  1 --> Predicted:  [1]
# Text:  i gotten better i proud much i --> Actual Label:  1 --> Predicted:  [1]
# Text:  whole life feels like dream --> Actual Label:  1 --> Predicted:  [1]
# Text:  morning feel blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  happy mood laughing loud --> Actual Label:  1 --> Predicted:  [0]
# Text:  love bad girl look --> Actual Label:  0 --> Predicted:  [0]
# Text:  god good blessed everything life oppounities --> Actual Label:  1 --> Predicted:  [0]
# Text:  laughing loud i sorry love --> Actual Label:  1 --> Predicted:  [0]
# Text:  blasting call maybe campus ti ame love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  thank god blessing life everyday --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life really going nothing compared pain depression --> Actual Label:  0 --> Predicted:  [0]
# Text:  point life know less faith people general --> Actual Label:  0 --> Predicted:  [0]
# Text:  i never cramps long life sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  god good blessed” --> Actual Label:  1 --> Predicted:  [0]
# Text:  look last years life i great --> Actual Label:  1 --> Predicted:  [1]
# Text:  happy prefer --> Actual Label:  1 --> Predicted:  [0]
# Text:  i --> Actual Label:  1 --> Predicted:  [0]
# Text:  na i feeling blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  best girlfriend ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  love way --> Actual Label:  1 --> Predicted:  [1]
# Text:  complaints i great --> Actual Label:  1 --> Predicted:  [0]
# Text:  reiatable dear 2013 want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  wish everything different --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  dont feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  love --> Actual Label:  1 --> Predicted:  [1]
# Text:  man i good üëç --> Actual Label:  1 --> Predicted:  [0]
# Text:  fml i uncomfoable --> Actual Label:  0 --> Predicted:  [1]
# Text:  always get screwed somehow life going good something happen mess --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear worst luck --> Actual Label:  0 --> Predicted:  [0]
# Text:  best friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  nye cannot believe happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  missed hate life fword fword fword --> Actual Label:  0 --> Predicted:  [1]
# Text:  loving life people --> Actual Label:  1 --> Predicted:  [0]
# Text:  need better life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  idea anything life great --> Actual Label:  1 --> Predicted:  [1]
# Text:  sure dont feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  wish happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life really hate --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate everything --> Actual Label:  0 --> Predicted:  [0]
# Text:  nahh i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  tired feeling like want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  dont feel good trigger happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel man --> Actual Label:  0 --> Predicted:  [0]
# Text:  awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  really want happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  could blame anyone hating since hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  lmao love ahh c --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good life clearly --> Actual Label:  0 --> Predicted:  [0]
# Text:  i feelin love --> Actual Label:  0 --> Predicted:  [1]
# Text:  nan --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  unhappy --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate much hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life man --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  hope everyones happy life miserable --> Actual Label:  0 --> Predicted:  [0]
# Text:  love plans --> Actual Label:  1 --> Predicted:  [0]
# Text:  really hate i --> Actual Label:  0 --> Predicted:  [1]
# Text:  worst luck --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sad huing --> Actual Label:  0 --> Predicted:  [1]
# Text:  eww i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  couple weeks 2013 i already stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  wanna die hate life everyone wrong --> Actual Label:  0 --> Predicted:  [0]
# Text:  laughing loud girl miserable --> Actual Label:  0 --> Predicted:  [0]
# Text:  man suck life --> Actual Label:  0 --> Predicted:  [1]
# Text:  get jealous anything --> Actual Label:  0 --> Predicted:  [1]
# Text:  fun --> Actual Label:  1 --> Predicted:  [0]
# Text:  truely happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life turned upside --> Actual Label:  0 --> Predicted:  [0]
# Text:  ‚äú love life äù --> Actual Label:  1 --> Predicted:  [1]
# Text:  cause life --> Actual Label:  0 --> Predicted:  [1]
# Text:  idea want --> Actual Label:  0 --> Predicted:  [0]
# Text:  best dog lt --> Actual Label:  1 --> Predicted:  [0]
# Text:  i feeling good --> Actual Label:  0 --> Predicted:  [0]
# Text:  stay bored cuz life --> Actual Label:  0 --> Predicted:  [0]
# Text:  andrewlaa hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  god i dull --> Actual Label:  0 --> Predicted:  [0]
# Text:  worst headache --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel damn good --> Actual Label:  1 --> Predicted:  [0]
# Text:  long day proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life wonderful minus bs --> Actual Label:  1 --> Predicted:  [0]
# Text:  want --> Actual Label:  0 --> Predicted:  [1]
# Text:  lord i contented --> Actual Label:  1 --> Predicted:  [0]
# Text:  nah i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  cause i ugly --> Actual Label:  0 --> Predicted:  [1]
# ...
# Text:  wow hate life thx 2 u paytoe16 --> Actual Label:  0 --> Predicted:  [1]
# Text:  i happy ‚ò∫ --> Actual Label:  1 --> Predicted:  [0]
# Text:  least sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  i good 2012 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i bad person honest --> Actual Label:  0 --> Predicted:  [0]
# Text:  need people life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i blessed much --> Actual Label:  1 --> Predicted:  [0]
# Text:  live sad lifelaughing loud nah kidding life freakin great dude --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good teacher --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  good i pretty good --> Actual Label:  1 --> Predicted:  [0]
# Text:  life sword hole wow --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [1]
# Text:  i damn comfy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i blessed 🙏 --> Actual Label:  1 --> Predicted:  [0]
# Text:  need head change --> Actual Label:  0 --> Predicted:  [0]
# Text:  anda wants yes life complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  life house sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  know satisfied --> Actual Label:  1 --> Predicted:  [0]
# Text:  i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  everything need --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy life anymore --> Actual Label:  0 --> Predicted:  [1]
# Text:  love trust 2 people life❤ need --> Actual Label:  1 --> Predicted:  [1]
# Text:  i actually happy i going tweet happy things --> Actual Label:  1 --> Predicted:  [1]
# Text:  i loving life --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good wee man --> Actual Label:  1 --> Predicted:  [1]
# Text:  want happy used --> Actual Label:  0 --> Predicted:  [1]
# Text:  wish could life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sad wtf --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear nothing life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [1]
# Text:  i tired people thinking i bad person --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  enjoying new life form4 --> Actual Label:  1 --> Predicted:  [0]
# Text:  wow life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  nope i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  fwordin love life 2012 damn good --> Actual Label:  1 --> Predicted:  [0]
# Text:  i really really sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  love feeling finally happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  think i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  real talk really like --> Actual Label:  1 --> Predicted:  [0]
# Text:  i pretty good --> Actual Label:  1 --> Predicted:  [0]
# Text:  life sucks bad wow --> Actual Label:  0 --> Predicted:  [0]
# Text:  love i --> Actual Label:  1 --> Predicted:  [1]
# Text:  yes i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  mother mary swear want change --> Actual Label:  0 --> Predicted:  [1]
# Text:  tired everything want die --> Actual Label:  0 --> Predicted:  [0]
# Text:  really hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  financial needs met i ammediately --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good mood --> Actual Label:  1 --> Predicted:  [1]
# Text:  i disappointed cant disappointed --> Actual Label:  0 --> Predicted:  [1]
# Text:  damn fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i amazing --> Actual Label:  1 --> Predicted:  [0]
# Text:  misery --> Actual Label:  0 --> Predicted:  [1]
# Text:  best friends ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  actually hate x --> Actual Label:  0 --> Predicted:  [0]
# Text:  crazy night many friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  drinking watching positive turning --> Actual Label:  1 --> Predicted:  [1]
# Text:  life terrible --> Actual Label:  0 --> Predicted:  [1]
# Text:  life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  glad god blessed girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  life great nothing else could ask --> Actual Label:  1 --> Predicted:  [0]
# Text:  best gf ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  dont know people seem love much hate bloody much --> Actual Label:  0 --> Predicted:  [0]
# Text:  blessed every day life blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  i falling love --> Actual Label:  1 --> Predicted:  [1]
# Text:  officially hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  life beautiful --> Actual Label:  1 --> Predicted:  [1]
# Text:  i living pretty good life --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword life laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  pretty boring life --> Actual Label:  0 --> Predicted:  [0]
# Text:  feel getting miserable --> Actual Label:  0 --> Predicted:  [0]
# Text:  best actually --> Actual Label:  1 --> Predicted:  [1]
# Text:  none --> Actual Label:  0 --> Predicted:  [1]
# Text:  life full empty promises broken dreams --> Actual Label:  0 --> Predicted:  [1]
# Text:  i hungry sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life people --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like good person --> Actual Label:  1 --> Predicted:  [0]
# Text:  want much --> Actual Label:  0 --> Predicted:  [1]
# Text:  hahaha love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy life rn --> Actual Label:  1 --> Predicted:  [1]
# Text:  depressed tt --> Actual Label:  0 --> Predicted:  [1]
# Text:  know i sitting hating life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life boring really hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good girl bad habits --> Actual Label:  1 --> Predicted:  [1]
# Text:  place i boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  want change background --> Actual Label:  0 --> Predicted:  [0]
# Text:  really dont feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  life fword mistake --> Actual Label:  0 --> Predicted:  [0]
# Text:  life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  trolaughing loud sobs good girl --> Actual Label:  1 --> Predicted:  [0]
# Text:  get sword done --> Actual Label:  0 --> Predicted:  [0]
# Text:  staing hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate college messed life --> Actual Label:  0 --> Predicted:  [1]
# Text:  like keep --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good enjoying life --> Actual Label:  1 --> Predicted:  [1]
# Text:  everything right want 2013 life good 20 old cannot complain hap --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life fword bull sword --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sweet --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good i --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  check twitter every 8 life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  omfg love --> Actual Label:  1 --> Predicted:  [1]
# Text:  suck life --> Actual Label:  0 --> Predicted:  [1]
# Text:  want die --> Actual Label:  0 --> Predicted:  [1]
# Text:  world awesome show world amazing life --> Actual Label:  1 --> Predicted:  [0]
# Text:  really happy atm --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy anymore --> Actual Label:  0 --> Predicted:  [0]
# Text:  cannot stop crying hate life family much --> Actual Label:  0 --> Predicted:  [1]
# Text:  i obsessed kno love --> Actual Label:  1 --> Predicted:  [0]
# Text:  sad life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i always depressed mood ffs --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  lalalalala life bitch likes target make everything good ti ames worse thanks life lovely lalalalala --> Actual Label:  0 --> Predicted:  [1]
# Text:  living good lifei love life style --> Actual Label:  1 --> Predicted:  [1]
# Text:  know always seem fword things life --> Actual Label:  0 --> Predicted:  [1]
# Text:  sorry sir love --> Actual Label:  1 --> Predicted:  [1]
# Text:  pay like enjoy life --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life seriously --> Actual Label:  1 --> Predicted:  [0]
# Text:  worst headache --> Actual Label:  0 --> Predicted:  [0]
# Text:  i never felt sick life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  reellcute loving single life tho --> Actual Label:  1 --> Predicted:  [1]
# Text:  i generally good person --> Actual Label:  1 --> Predicted:  [0]
# Text:  wish happy life --> Actual Label:  0 --> Predicted:  [0]
# Text:  live pretty fabulous life --> Actual Label:  1 --> Predicted:  [1]
# Text:  want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  one life enjoy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i going mia love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  i got best friends ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  i stressed ridiculous --> Actual Label:  0 --> Predicted:  [1]
# Text:  finally enjoy college life --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword man life --> Actual Label:  0 --> Predicted:  [0]
# Text:  oh god best dad ever ☺ --> Actual Label:  1 --> Predicted:  [1]
# Text:  wish suck --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life ti ame sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  honestly love life thanks --> Actual Label:  1 --> Predicted:  [0]
# Text:  i even mad anymore i calm content --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bored hate life even left house week go gym --> Actual Label:  0 --> Predicted:  [0]
# Text:  changed life love 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i full sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  dude life love --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel good trigga happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i way tired life --> Actual Label:  0 --> Predicted:  [0]
# Text:  feel boredom --> Actual Label:  0 --> Predicted:  [0]
# Text:  life fword sucks ass --> Actual Label:  0 --> Predicted:  [0]
# Text:  someone save i gona boredom --> Actual Label:  0 --> Predicted:  [1]
# Text:  want --> Actual Label:  0 --> Predicted:  [1]
# Text:  worst nightmares --> Actual Label:  0 --> Predicted:  [1]
# Text:  want --> Actual Label:  1 --> Predicted:  [0]
# Text:  really happy life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate much love hi --> Actual Label:  0 --> Predicted:  [1]
# Text:  awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  good feeling things --> Actual Label:  1 --> Predicted:  [0]
# Text:  life 3 --> Actual Label:  1 --> Predicted:  [1]
# Text:  make life complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  happy amazing people life --> Actual Label:  1 --> Predicted:  [0]
# Text:  cares life hell laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  i already love --> Actual Label:  1 --> Predicted:  [0]
# Text:  mean i pretty fword awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  want happy use --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy life complete call sweet thang --> Actual Label:  1 --> Predicted:  [0]
# Text:  guess i depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  life sooo fworded --> Actual Label:  0 --> Predicted:  [0]
# Text:  life boring oh god --> Actual Label:  0 --> Predicted:  [0]
# Text:  life ass --> Actual Label:  0 --> Predicted:  [1]
# Text:  swear sword happens --> Actual Label:  0 --> Predicted:  [0]
# Text:  life big --> Actual Label:  0 --> Predicted:  [0]
# Text:  nahh i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  life i living nothing blessing --> Actual Label:  1 --> Predicted:  [1]
# Text:  laughing loud life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sick --> Actual Label:  0 --> Predicted:  [1]
# Text:  loving life regardless tries stop p --> Actual Label:  1 --> Predicted:  [1]
# Text:  could never right --> Actual Label:  0 --> Predicted:  [0]
# Text:  life could better sisters fword amazing --> Actual Label:  1 --> Predicted:  [0]
# Text:  cannot believe sword called life --> Actual Label:  0 --> Predicted:  [0]
# Text:  good friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  something want within reach --> Actual Label:  0 --> Predicted:  [0]
# Text:  honestly sword oh god literally --> Actual Label:  0 --> Predicted:  [0]
# Text:  i getting boring life hm hm --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  happy finally found good man --> Actual Label:  1 --> Predicted:  [0]
# Text:  true life cannot sex sad smh --> Actual Label:  0 --> Predicted:  [0]
# Text:  kinda love young life --> Actual Label:  1 --> Predicted:  [1]
# Text:  damn best boyfriend --> Actual Label:  1 --> Predicted:  [1]
# Text:  best major ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  good job --> Actual Label:  1 --> Predicted:  [1]
# Text:  want happy let please --> Actual Label:  0 --> Predicted:  [0]
# Text:  love looking --> Actual Label:  1 --> Predicted:  [1]
# Text:  okay i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  life good complain much goodfamily butgoodfamily --> Actual Label:  1 --> Predicted:  [0]
# Text:  chased good life whole life long looked back life whole life gone go wrong --> Actual Label:  0 --> Predicted:  [1]
# Text:  day leave everything going great --> Actual Label:  1 --> Predicted:  [0]
# Text:  awesome i quite happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel like disappointment everyone --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  life lie --> Actual Label:  0 --> Predicted:  [0]
# Text:  forgive i flawed --> Actual Label:  0 --> Predicted:  [1]
# Text:  i i feeling sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  bestest friends ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  could easily complain things wrong life much good need --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life mess --> Actual Label:  0 --> Predicted:  [1]
# Text:  found life good happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i love jesse pitch perfect --> Actual Label:  1 --> Predicted:  [0]
# Text:  would trade life --> Actual Label:  1 --> Predicted:  [0]
# Text:  go i triple blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  know made right decision could happier --> Actual Label:  1 --> Predicted:  [0]
# Text:  enjoy life --> Actual Label:  1 --> Predicted:  [0]
# Text:  one happy girl tonite --> Actual Label:  1 --> Predicted:  [1]
# Text:  horrible life --> Actual Label:  0 --> Predicted:  [0]
# Text:  sad ti ame --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate looking mirror --> Actual Label:  0 --> Predicted:  [0]
# Text:  go like little depression moods even know depression --> Actual Label:  0 --> Predicted:  [0]
# Text:  know i perfect --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  none --> Actual Label:  0 --> Predicted:  [0]
# Text:  happy girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  anything want bc got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  much love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  bitch want --> Actual Label:  1 --> Predicted:  [1]
# Text:  hi i good --> Actual Label:  1 --> Predicted:  [0]

# %% [markdown]
# ### Predict on Unseen Data

# %%
nd1 = ["i am the happiest person in this world"]
nd2 = ['i am excited']
nd3 = ['i would not change the past if I could']
nd4 = ['i get everything i want']
nd5 = ['everyday of my life is a celebration']
nd6 = ['my life is blessed']
nd7 = ['i feel complete']
nd8 = ['thank you god']
nd9 = ['i love my family']
nd10 = ['i am in a great mood']
nd11 = ['i never feel sad']   
nd12 = ['i hate chocolate']         

nd1pad = vect.texts_to_sequences(nd1)
nd1pad = pad_sequences(nd1pad, maxlen=9, padding='post')
prednd1 = model.predict_classes(nd1pad).item()
#prednd1a = (model.predict(nd1pad) > 0.5).astype("int32")
#prednd1c = np.argmax(prednd1)
#print(prednd1a, prednd1b, prednd1c)


nd2pad = vect.texts_to_sequences(nd2)
nd2pad = pad_sequences(nd2pad, maxlen=3, padding='post')
prednd2 = model.predict_classes(nd2pad).item()


nd3pad = vect.texts_to_sequences(nd3)
nd3pad = pad_sequences(nd3pad, maxlen=9, padding='post')
prednd3 = model.predict_classes(nd3pad).item()

nd4pad = vect.texts_to_sequences(nd4)
nd4pad = pad_sequences(nd4pad, maxlen=5, padding='post')
prednd4 = model.predict_classes(nd4pad).item()

nd5pad = vect.texts_to_sequences(nd5)
nd5pad = pad_sequences(nd5pad, maxlen=7, padding='post')
prednd5 = model.predict_classes(nd5pad).item()

nd6pad = vect.texts_to_sequences(nd6)
nd6pad = pad_sequences(nd6pad, maxlen=4, padding='post')
prednd6 = model.predict_classes(nd6pad).item()


nd7pad = vect.texts_to_sequences(nd7)
nd7pad = pad_sequences(nd7pad, maxlen=3, padding='post')
prednd7 = model.predict_classes(nd7pad).item()

nd8pad = vect.texts_to_sequences(nd8)
nd8pad = pad_sequences(nd8pad, maxlen=3, padding='post')
prednd8 = model.predict_classes(nd8pad).item()

nd9pad = vect.texts_to_sequences(nd9)
nd9pad = pad_sequences(nd9pad, maxlen=4, padding='post')
prednd9 = model.predict_classes(nd9pad).item()

nd10pad = vect.texts_to_sequences(nd10)
nd10pad = pad_sequences(nd10pad, maxlen=8, padding='post')
prednd10 = model.predict_classes(nd10pad).item()

nd11pad = vect.texts_to_sequences(nd11)
nd11pad = pad_sequences(nd11pad, maxlen=4, padding='post')
prednd11 = model.predict_classes(nd11pad).item()

nd12pad = vect.texts_to_sequences(nd12)
nd12pad = pad_sequences(nd12pad, maxlen=3, padding='post')
prednd12 = model.predict_classes(nd12pad).item()
#prednd12 = (model.predict(nd12pad) > 0.5).astype("int32")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 9).
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print("Text: ",nd1, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd1)
print("Text: ",nd2, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd2)
print("Text: ",nd3, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd3)
print("Text: ",nd4, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd4)
print("Text: ",nd5, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd5)
print("Text: ",nd6, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd6)
print("Text: ",nd7, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd7)
print("Text: ",nd8, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd8)
print("Text: ",nd9, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd9)
print("Text: ",nd10, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd10)
print("Text: ",nd11, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd11)
print("Text: ",nd12, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd12)
# Out:
# Text:  ['i am the happiest person in this world'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i am excited'] --> Actual Label:  1 --> Predicted:  0
# Text:  ['i would not change the past if I could'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i get everything i want'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['everyday of my life is a celebration'] --> Actual Label:  1 --> Predicted:  0
# Text:  ['my life is blessed'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i feel complete'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['thank you god'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i love my family'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i am in a great mood'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i never feel sad'] --> Actual Label:  1 --> Predicted:  0
# Text:  ['i hate chocolate'] --> Actual Label:  1 --> Predicted:  0

# %%
d1 = ['i have lost in life']
d2 = ['why do i have to be sad']
d3 = ['i have never been so disappointed in life']
d4 = ['i feel like crying'] 
d5 = ['i hate the world'] 
d6 = ['why is everything so hard'] 
d7 = ['i feel miserable']
d8 = ['i live in a terrible place'] 
d9 = ['i cry all day'] 
d10 = ['i am not lucky nor blessed']
d11 = ['nobody loves me']
d12 = ['i am unlucky']         

d1pad = vect.texts_to_sequences(d1)
d1pad = pad_sequences(nd1pad, maxlen=6, padding='post')
#prednd1 = (model.predict(nd1pad) > 0.5).astype("int32")
predd1 = model.predict_classes(d1pad).item()


d2pad = vect.texts_to_sequences(d2)
d2pad = pad_sequences(d2pad, maxlen=7, padding='post')
predd2 = model.predict_classes(d2pad).item()

d3pad = vect.texts_to_sequences(d3)
d3pad = pad_sequences(d3pad, maxlen=8, padding='post')
predd3 = model.predict_classes(d3pad).item()

d4pad = vect.texts_to_sequences(d4)
d4pad = pad_sequences(d4pad, maxlen=4, padding='post')
predd4 = model.predict_classes(d4pad).item()

d5pad = vect.texts_to_sequences(d5)
d5pad = pad_sequences(d5pad, maxlen=4, padding='post')
predd5 = model.predict_classes(d5pad)
predd5 = np.argmax(predd5)

d6pad = vect.texts_to_sequences(d6)
d6pad = pad_sequences(d6pad, maxlen=5, padding='post')
predd6 = model.predict_classes(d6pad).item()

d7pad = vect.texts_to_sequences(d7)
d7pad = pad_sequences(d7pad, maxlen=3, padding='post')
predd7 = model.predict_classes(d7pad).item()

d8pad = vect.texts_to_sequences(d8)
d8pad = pad_sequences(d8pad, maxlen=4, padding='post')
predd8 = model.predict_classes(d8pad).item()

d9pad = vect.texts_to_sequences(d9)
d9pad = pad_sequences(d9pad, maxlen=4, padding='post')
predd9 = model.predict_classes(d9pad).item()

d10pad = vect.texts_to_sequences(d10)
d10pad = pad_sequences(d10pad, maxlen=6, padding='post')
predd10 = model.predict_classes(d10pad).item()

d11pad = vect.texts_to_sequences(d11)
d11pad = pad_sequences(d11pad, maxlen=3, padding='post')
predd11 = model.predict_classes(d11pad).item()

d12pad = vect.texts_to_sequences(d12)
d12pad = pad_sequences(d12pad, maxlen=5, padding='post')
predd12 = model.predict_classes(d12pad).item()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print("Text: ",d1, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd1)
print("Text: ",d2, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd2)
print("Text: ",d3, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd3)
print("Text: ",d4, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd4)
print("Text: ",d5, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd5)
print("Text: ",d6, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd6)
print("Text: ",d7, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd7)
print("Text: ",d8, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd8)
print("Text: ",d9, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd9)
print("Text: ",d10, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd10)
print("Text: ",d11, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd11)
print("Text: ",d12, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd12)
# Out:
# Text:  ['i have lost in life'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['why do i have to be sad'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i have never been so disappointed in life'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i feel like crying'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i hate the world'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['why is everything so hard'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i feel miserable'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i live in a terrible place'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i cry all day'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i am not lucky nor blessed'] --> Actual Label:  0 --> Predicted:  1
# Text:  ['nobody loves me'] --> Actual Label:  0 --> Predicted:  1
# Text:  ['i am unlucky'] --> Actual Label:  0 --> Predicted:  1

# %%
# Read as a dataframe 
metrics = pd.DataFrame(history.history)
metrics.rename(columns = {'loss': 'Training_Loss', 'accuracy': 'Training_Accuracy', 'val_loss': 'Validation_Loss', 'val_accuracy': 'Validation_Accuracy'}, inplace = True)
def plot_graphs1(var1, var2, string):
    metrics[[var1, var2]].plot()
    plt.title('Training and Validation ' + string)
    plt.xlabel ('Number of epochs')
    plt.ylabel(string)
    plt.legend([var1, var2])

# %%
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
plot_graphs1('Training_Loss', 'Validation_Loss', 'loss')

# %%
plot_graphs1('Training_Accuracy', 'Validation_Accuracy', 'accuracy')

# %% [markdown]
# ### Metrics

# %%
#pred = model.predict(padded_docs_test)
#pred = pred.round()
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[772  65]
#  [102 824]]

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in
                cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cm, annot=labels, fmt='', cmap='Reds')

# %%
print(classification_report(y_test,pred))
print("Accuracy: ", accuracy_score(y_test, pred))
print("F1: ", f1_score(y_test, pred))
print("Precision: ", precision_score(y_test, pred))
print("Recall: ", recall_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       837
#            1       0.93      0.89      0.91       926
#
#     accuracy                           0.91      1763
#    macro avg       0.91      0.91      0.91      1763
# weighted avg       0.91      0.91      0.91      1763
#
# Accuracy:  0.9052750992626205
# F1:  0.9079889807162534
# Precision:  0.9268841394825647
# Recall:  0.8898488120950324
