# %% [markdown]
# # Gated Recurrent Unit GloVe

# %% [markdown]
# ###Reference
# data representation techniques (Tokenizer() class, Word2Vec and GloVe embedding): 'Deep Learning with Python' by Francois Chollet, 'Implement neural networks with Keras on Theano and TensorFlow' by Sujit Pal et al.
#
# spam detection example: https://towardsdatascience.com/nlp-spam-detection-in-sms-text-data-using-deep-learning-b8632db85cc8
#
# recurrent layers: https://keras.io/api/layers/recurrent_layers/

# %% [markdown]
# ###Mounting to Google Drive

# %%
#connecting gdrive into the google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Import Libraries

# %%
# import libraries
import pandas as pd
import gensim
import nltk
nltk.download('punkt')
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

from keras.constraints import max_norm
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers.recurrent import LSTM
from keras.layers import Activation, Dense, Dropout, Flatten, SimpleRNN
from keras.initializers import Constant

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score
from sklearn.metrics import classification_report
import seaborn as sns
from tensorflow.keras.utils import plot_model
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ####Load the Dataset

# %%
#load the dataset - change file path 
data=pd.read_csv("/content/gdrive/MyDrive/Depression Project/DepressionDataFinal2Processed.csv")
data = data.astype(str)
data["Target"] = data["Target"].astype(str).astype(int)
data.head()
# Out:
#          Id                                            Text  Target
# 0  2.85e+17   one thing love life mother one ever come mine       1
# 1   2.9e+17                         want perfect want happy       0
# 2  2.86e+17  mom hates dad hates today sucks fword life tho       0
# 3  2.86e+17                                  hate hate life       0
# 4  2.86e+17                                       feel good       1

# %%
data.columns
# Out:
# Index(['Id', 'Text', 'Target'], dtype='object')

# %% [markdown]
# ### Train, Val, Test split --> 60%, 20%, 20%

# %%
# # train, val, test split --> 60%, 20%, 20% 
# # x_train is the training data set
# # y_test is the corresponding labels to x_train 
# # x_test is the test dataset 
# # y_test is the corresponding label to x_test 
x_train, x_test, y_train, y_test = train_test_split(data, data.Target, test_size=0.2, random_state=1)
# # 0.25 x 0.8 = 0.2
x_train, x_val, y_train, y_val = train_test_split(data, data.Target, test_size=0.25, random_state=1)

# %% [markdown]
# ### Constant

# %%
max_len = 20
EMBEDDING_DIM = 200
num_words = 8400

# %% [markdown]
# ### Tokenize tweets using Tokenizer()

# %%
# Tokenizer API used to encode each word as a number 
vect = Tokenizer()
total_reviews = x_train + x_test + x_val
vect.fit_on_texts(total_reviews)

# %% [markdown]
# ### Turn the Vectorized Tokens into Sequences of Integers

# %%
encoded_docs_train = vect.texts_to_sequences(x_train)
encoded_docs_test = vect.texts_to_sequences(x_test)
encoded_docs_val = vect.texts_to_sequences(x_val)

# %% [markdown]
# ### Padding and Making all the Sequences the same Length

# %%
# pad sequence
padded_docs_train = pad_sequences(encoded_docs_train, maxlen=max_len, padding="post")
padded_docs_test = pad_sequences(encoded_docs_test, maxlen=max_len, padding="post")
padded_docs_val = pad_sequences(encoded_docs_val, maxlen=max_len, padding="post")

# %% [markdown]
# ### Find number of tokens in List

# %%
# add tokens in text column in a list 
# find number of tokens in list
review_lines = list()
lines = data["Text"].values.tolist()

# %%
for line in lines:
  tokens = word_tokenize(line)
  review_lines.append(tokens)

# %%
len(review_lines)
# Out:
# 8815

# %% [markdown]
# ### Open Pre-trained GloVe model and Finetune

# %%
### Glove 
glove_vectors = dict()

# %%
#https://nlp.stanford.edu/projects/glove/ - The GloVe model was downloaded from this link 
#(download 'glove.twitter.27B.zip' file and use 200 dimensional model)
f = open('/content/gdrive/MyDrive/Depression Project/glovetwitter27B200d.txt', encoding = "utf-8")

for line in f:
  values = line.split()
  # the word 
  word = values[0]
  # its vector values 
  coefs = np.asarray(values[1:])
  glove_vectors[word] = coefs
f.close()

# %%
#unique words that are represented
len(glove_vectors.keys())
# Out:
# 1193514

# %%
# global vector 
glove_vectors.get('celebration')
# Out:
# array(['-0.27784', '-0.048215', '0.63133', '-0.05642', '0.19216',
#        '-0.1174', '0.80024', '0.26859', '0.071219', '0.13263', '-0.30703',
#        '0.038107', '-0.44552', '0.48916', '0.32701', '-0.049554',
#        '0.013325', '0.32327', '-0.54172', '0.17378', '-0.23314',
#        '0.35102', '-0.3803', '0.033209', '0.2233', '0.86731', '-0.16913',
#        '-0.5625', '-0.079653', '0.37033', '0.33603', '-0.16263',
#        '-0.29979', '-0.12484', '-0.16321', '0.25508', '0.29101',
#        '-0.23266', '0.13849', '-0.45288', '0.53965', '0.2613', '0.15371',
#        '0.42275', '-0.54033', '0.13873', '-0.41465', '-0.069931',
#        '-0.52907', '-0.043219', '-0.13219', '-0.6244', '0.044825',
#        '-0.040964', '0.12103', '-0.034205', '0.21233', '-0.41992',
#        '-0.30528', '-0.21269', '0.1868', '0.16613', '-0.765', '0.38523',
#        '-0.53546', '-0.097203', '0.15492', '-0.1075', '0.18992',
#        '0.014092', '-0.28004', '-0.52623', '0.50529', '0.54127',
#        '0.58955', '-0.43736', '0.36226', '0.49071', '-0.17219',
#        '0.064432', '1.0116', '-0.097541', '0.53053', '-0.19558',
#        '-0.24522', '-0.035578', '0.78686', '0.50568', '0.5245',
#        '-0.09567', '0.21012', '-0.0083826', '-0.89907', '-0.69908',
#        '0.4843', '-0.46322', '0.3673', '0.35796', '-0.030859', '-0.21896',
#        '-0.42716', '0.079786', '0.20886', '0.25489', '-0.23506',
#        '-0.55939', '-0.09702', '0.43305', '-0.46057', '0.13799',
#        '0.57033', '-0.11648', '-0.02916', '-0.38847', '-0.13282',
#        '-0.30431', '-0.11078', '-0.33413', '0.23761', '0.56378',
#        '0.04359', '-0.088743', '-0.07201', '0.04435', '0.19871',
#        '0.063163', '-0.31964', '-0.42892', '0.33091', '-0.0060779',
#        '0.48587', '-0.29165', '0.15909', '-0.64736', '-0.21574',
#        '-0.20389', '-0.4187', '0.31599', '-0.58968', '0.4576', '-0.16404',
#        '-0.076589', '-0.40494', '0.012771', '-0.48121', '-0.71679',
#        '0.48094', '-0.63129', '-0.23565', '0.41649', '-0.010051',
#        '0.23739', '-2.7267', '-0.29286', '-0.11672', '-0.4973',
#        '-0.41548', '0.14965', '0.083759', '0.24244', '-0.39123',
#        '-0.2507', '-0.11103', '-0.070963', '-0.17396', '0.18303',
#        '0.28555', '-0.42546', '0.50536', '0.0061286', '0.32492',
#        '-0.016649', '0.12893', '-0.046452', '0.82452', '0.070299',
#        '0.32154', '-0.49957', '0.23741', '-0.11111', '-0.36552',
#        '-0.39339', '-0.49637', '0.46689', '-0.28417', '-0.468', '0.26563',
#        '-0.43454', '-0.42636', '0.084216', '-0.52721', '0.055468',
#        '0.21887', '-0.093932', '0.13431', '0.45018', '0.55479', '-0.1476',
#        '0.41456', '-0.081629'], dtype='<U10')

# %%
# get vector for tweets dataset 
#embedding_vector = {}
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

for word, i in vect.word_index.items():
  embedding_vector = glove_vectors.get(word)
  # words not found in embedding index will be 0 
  if embedding_vector is not None:
    embedding_matrix[i] = embedding_vector
  else:
    print(word)

# %% [markdown]
# ### Tokenize, Vectorize, turn it into sequence and Pad again

# %%
# vectorise tweets 
vect = Tokenizer()
vect.fit_on_texts(review_lines)
sequences = vect.texts_to_sequences(review_lines)

# %%
word_index = vect.word_index
print (len(word_index))
# Out:
# 1984

# %%
# pad sequence 
review_pad = pad_sequences(sequences, maxlen = max_len)
sentiment = data["Target"].values

# %% [markdown]
# ### Build and compile DL Model

# %%
model = Sequential()
embedding_layer = Embedding(num_words, EMBEDDING_DIM, input_length= max_len, weights = [embedding_matrix])
# Configuring the parameters
model.add(embedding_layer)
model.add(layers.GRU(45))
model.add(Dropout(0.7))
# Adding a dense output layer with sigmoid activation
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 200)           1680000
# _________________________________________________________________
# gru (GRU)                    (None, 45)                33345
# _________________________________________________________________
# dropout (Dropout)            (None, 45)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 46
# =================================================================
# Total params: 1,713,391
# Trainable params: 1,713,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot NN model 
plot_model(model, to_file='/content/gdrive/MyDrive/Depression Project/mlp-mnist.png', show_shapes=True)

# %% [markdown]
# ### Split Validation Dataset

# %%
validation_split = 0.2 
indices = np.arange(review_pad.shape[0])
print(np.random.shuffle(indices))
review_pad = review_pad[indices]
sentiment = sentiment[indices]
num_validation_samples = int(validation_split * review_pad.shape[0])
print(num_validation_samples)
# Out:
# None
# 1763

# %%
padded_docs_train = review_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
padded_docs_cv = padded_docs_train[-num_validation_samples:]
y_val = y_train[-num_validation_samples:]
padded_docs_test = review_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

# %%
# compile the model 
opt = tf.keras.optimizers.RMSprop(learning_rate=0.001, momentum=0.4)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(padded_docs_train, y_train,
                    epochs=50, batch_size=50, 
                    validation_data = (padded_docs_cv, y_val)
                    )
model.save('model.h5')
# Out:
# Epoch 1/50
# 142/142 [==============================] - 6s 23ms/step - loss: 0.5498 - accuracy: 0.7176 - val_loss: 0.3221 - val_accuracy: 0.8684
# Epoch 2/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.2081 - accuracy: 0.9264 - val_loss: 0.1533 - val_accuracy: 0.9433
# Epoch 3/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.1749 - accuracy: 0.9384 - val_loss: 0.1330 - val_accuracy: 0.9529
# Epoch 4/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.1374 - accuracy: 0.9534 - val_loss: 0.1119 - val_accuracy: 0.9643
# Epoch 5/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.1163 - accuracy: 0.9614 - val_loss: 0.1009 - val_accuracy: 0.9665
# Epoch 6/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.1155 - accuracy: 0.9610 - val_loss: 0.0990 - val_accuracy: 0.9643
# Epoch 7/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.1135 - accuracy: 0.9638 - val_loss: 0.0971 - val_accuracy: 0.9665
# Epoch 8/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0986 - accuracy: 0.9650 - val_loss: 0.0809 - val_accuracy: 0.9716
# Epoch 9/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.1059 - accuracy: 0.9652 - val_loss: 0.0735 - val_accuracy: 0.9762
# Epoch 10/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.1092 - accuracy: 0.9669 - val_loss: 0.0718 - val_accuracy: 0.9773
# Epoch 11/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0917 - accuracy: 0.9719 - val_loss: 0.0697 - val_accuracy: 0.9773
# Epoch 12/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0797 - accuracy: 0.9748 - val_loss: 0.0721 - val_accuracy: 0.9756
# Epoch 13/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0722 - accuracy: 0.9771 - val_loss: 0.0639 - val_accuracy: 0.9784
# Epoch 14/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0649 - accuracy: 0.9765 - val_loss: 0.0627 - val_accuracy: 0.9767
# Epoch 15/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0713 - accuracy: 0.9776 - val_loss: 0.0554 - val_accuracy: 0.9813
# Epoch 16/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0711 - accuracy: 0.9747 - val_loss: 0.0594 - val_accuracy: 0.9790
# Epoch 17/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0801 - accuracy: 0.9711 - val_loss: 0.0599 - val_accuracy: 0.9779
# Epoch 18/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0734 - accuracy: 0.9767 - val_loss: 0.0595 - val_accuracy: 0.9779
# Epoch 19/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0704 - accuracy: 0.9775 - val_loss: 0.0588 - val_accuracy: 0.9779
# Epoch 20/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0661 - accuracy: 0.9781 - val_loss: 0.0617 - val_accuracy: 0.9784
# Epoch 21/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0606 - accuracy: 0.9805 - val_loss: 0.0554 - val_accuracy: 0.9813
# Epoch 22/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0614 - accuracy: 0.9790 - val_loss: 0.0536 - val_accuracy: 0.9796
# Epoch 23/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0558 - accuracy: 0.9798 - val_loss: 0.0556 - val_accuracy: 0.9801
# Epoch 24/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0636 - accuracy: 0.9750 - val_loss: 0.0562 - val_accuracy: 0.9818
# Epoch 25/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0561 - accuracy: 0.9802 - val_loss: 0.0547 - val_accuracy: 0.9813
# Epoch 26/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0590 - accuracy: 0.9787 - val_loss: 0.0525 - val_accuracy: 0.9807
# Epoch 27/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0621 - accuracy: 0.9784 - val_loss: 0.0536 - val_accuracy: 0.9790
# Epoch 28/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0529 - accuracy: 0.9811 - val_loss: 0.0501 - val_accuracy: 0.9807
# Epoch 29/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0598 - accuracy: 0.9764 - val_loss: 0.0525 - val_accuracy: 0.9796
# Epoch 30/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0514 - accuracy: 0.9810 - val_loss: 0.0492 - val_accuracy: 0.9813
# Epoch 31/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0549 - accuracy: 0.9804 - val_loss: 0.0525 - val_accuracy: 0.9818
# Epoch 32/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0570 - accuracy: 0.9808 - val_loss: 0.0524 - val_accuracy: 0.9824
# Epoch 33/50
# 142/142 [==============================] - 3s 22ms/step - loss: 0.0551 - accuracy: 0.9808 - val_loss: 0.0477 - val_accuracy: 0.9830
# Epoch 34/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0562 - accuracy: 0.9787 - val_loss: 0.0510 - val_accuracy: 0.9824
# Epoch 35/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0576 - accuracy: 0.9792 - val_loss: 0.1027 - val_accuracy: 0.9682
# Epoch 36/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0511 - accuracy: 0.9788 - val_loss: 0.0467 - val_accuracy: 0.9824
# Epoch 37/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0530 - accuracy: 0.9792 - val_loss: 0.0485 - val_accuracy: 0.9830
# Epoch 38/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0450 - accuracy: 0.9858 - val_loss: 0.0448 - val_accuracy: 0.9841
# Epoch 39/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0475 - accuracy: 0.9823 - val_loss: 0.0455 - val_accuracy: 0.9824
# Epoch 40/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0512 - accuracy: 0.9804 - val_loss: 0.0446 - val_accuracy: 0.9836
# Epoch 41/50
# 142/142 [==============================] - 3s 22ms/step - loss: 0.0468 - accuracy: 0.9813 - val_loss: 0.0427 - val_accuracy: 0.9836
# Epoch 42/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0449 - accuracy: 0.9823 - val_loss: 0.0432 - val_accuracy: 0.9853
# Epoch 43/50
# 142/142 [==============================] - 3s 23ms/step - loss: 0.0513 - accuracy: 0.9823 - val_loss: 0.0455 - val_accuracy: 0.9830
# Epoch 44/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0458 - accuracy: 0.9828 - val_loss: 0.0451 - val_accuracy: 0.9847
# Epoch 45/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0472 - accuracy: 0.9830 - val_loss: 0.0409 - val_accuracy: 0.9858
# Epoch 46/50
# 142/142 [==============================] - 3s 22ms/step - loss: 0.0429 - accuracy: 0.9822 - val_loss: 0.0451 - val_accuracy: 0.9824
# Epoch 47/50
# 142/142 [==============================] - 3s 20ms/step - loss: 0.0477 - accuracy: 0.9805 - val_loss: 0.0440 - val_accuracy: 0.9853
# Epoch 48/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0428 - accuracy: 0.9853 - val_loss: 0.0422 - val_accuracy: 0.9830
# Epoch 49/50
# 142/142 [==============================] - 3s 21ms/step - loss: 0.0463 - accuracy: 0.9819 - val_loss: 0.0421 - val_accuracy: 0.9836
# Epoch 50/50
# 142/142 [==============================] - 3s 19ms/step - loss: 0.0379 - accuracy: 0.9865 - val_loss: 0.0388 - val_accuracy: 0.9847

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(padded_docs_test, y_test)
# Out:
# 56/56 [==============================] - 0s 6ms/step - loss: 0.2871 - accuracy: 0.9399
# [0.2871100604534149, 0.9398751854896545]

# %%
x_test.head()
# Out:
#             Id                            Text  Target
# 2143   2.9e+17                     social life       0
# 2181   2.9e+17                    good friends       1
# 4425  2.85e+17  listening love cause hate life       0
# 2577   2.9e+17           love never gets bored       1
# 2213   2.9e+17             best boyfriend ever       1

# %%
pred = model.predict_classes(padded_docs_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
text = x_test["Text"]

# %%
for i in range(1763):
  print("Text: ",x_test["Text"].iloc[i], "-->", "Actual Label: ", x_test["Target"].iloc[i], "-->", "Predicted: ", pred[i])
# Out:
# Text:  social life --> Actual Label:  0 --> Predicted:  [1]
# Text:  good friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  listening love cause hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  love never gets bored --> Actual Label:  1 --> Predicted:  [0]
# Text:  best boyfriend ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  wow suck --> Actual Label:  0 --> Predicted:  [0]
# Text:  life series unfounate fworded events --> Actual Label:  0 --> Predicted:  [0]
# Text:  god bless --> Actual Label:  1 --> Predicted:  [0]
# Text:  yes i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i ame life i loving every single moment --> Actual Label:  1 --> Predicted:  [0]
# Text:  i feeling great --> Actual Label:  1 --> Predicted:  [1]
# Text:  i made like worst mistakes ever --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  new resolution drink life fword terrible --> Actual Label:  0 --> Predicted:  [0]
# Text:  love looking --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like proud parent --> Actual Label:  1 --> Predicted:  [1]
# Text:  introve love --> Actual Label:  1 --> Predicted:  [1]
# Text:  goals life --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword sword fword life hate fword dad fword --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never many emotional days life good --> Actual Label:  1 --> Predicted:  [0]
# Text:  little bit still love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  good thanks asking --> Actual Label:  1 --> Predicted:  [1]
# Text:  want --> Actual Label:  1 --> Predicted:  [0]
# Text:  may get want get need i satisfied go outsearch constant new fulfillment --> Actual Label:  1 --> Predicted:  [0]
# Text:  blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  really happy going well though --> Actual Label:  1 --> Predicted:  [1]
# Text:  want alone miserable life u wanna make fun i fully aware existence --> Actual Label:  0 --> Predicted:  [0]
# Text:  enjoy life yeah --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  stressed could --> Actual Label:  0 --> Predicted:  [0]
# Text:  like i proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  wtf wtf wtf yes yes yes happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  wow love happy laughing loud --> Actual Label:  1 --> Predicted:  [1]
# Text:  i really unhappy try --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  best friends ever haha --> Actual Label:  1 --> Predicted:  [1]
# Text:  wishes come true --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life matter good bad know god always enough --> Actual Label:  1 --> Predicted:  [1]
# Text:  nrlynairdna allah thank giving happiness friends well need happiness --> Actual Label:  1 --> Predicted:  [0]
# Text:  one proud friend --> Actual Label:  1 --> Predicted:  [0]
# Text:  get want --> Actual Label:  1 --> Predicted:  [1]
# Text:  i never sick life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate feel alone --> Actual Label:  0 --> Predicted:  [0]
# Text:  i far perfect --> Actual Label:  0 --> Predicted:  [1]
# Text:  “ tripping life great --> Actual Label:  1 --> Predicted:  [0]
# Text:  really fast metabolism love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  bestest friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sorry suck --> Actual Label:  0 --> Predicted:  [1]
# Text:  i love --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bad girl3 --> Actual Label:  0 --> Predicted:  [0]
# Text:  want friends want happy want die --> Actual Label:  0 --> Predicted:  [1]
# Text:  nope i amazing --> Actual Label:  1 --> Predicted:  [1]
# Text:  xxboybelieberxx miss happy little kid --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  ah life totally complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  i actually sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  damn love --> Actual Label:  1 --> Predicted:  [0]
# Text:  worst back problems --> Actual Label:  0 --> Predicted:  [1]
# Text:  oh even describe beautiful life --> Actual Label:  1 --> Predicted:  [0]
# Text:  lool nah i proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  naw naw i good boy laughing loud --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good ready i shall i ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate embarrassing 😒 --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  going make new years resolution i happy life way --> Actual Label:  1 --> Predicted:  [0]
# Text:  yay life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  really good real friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  honestly think worst luck tho --> Actual Label:  0 --> Predicted:  [0]
# Text:  want die right --> Actual Label:  0 --> Predicted:  [0]
# Text:  i got pocket full sunshine --> Actual Label:  1 --> Predicted:  [1]
# Text:  millipede amazing --> Actual Label:  1 --> Predicted:  [1]
# Text:  yes i good boy haha --> Actual Label:  1 --> Predicted:  [1]
# Text:  oh god i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  love --> Actual Label:  1 --> Predicted:  [0]
# Text:  like living kinda lifei living blessed life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sick always feeling sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel fine feel good --> Actual Label:  1 --> Predicted:  [1]
# Text:  amazing everything need life complete happy blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  best best friend ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  suppose act happy i --> Actual Label:  0 --> Predicted:  [0]
# Text:  want happy use --> Actual Label:  0 --> Predicted:  [1]
# Text:  thank god waking blessing --> Actual Label:  1 --> Predicted:  [1]
# Text:  never happy fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  stressed depressed lets face i mess --> Actual Label:  0 --> Predicted:  [1]
# Text:  always get want eventually --> Actual Label:  1 --> Predicted:  [0]
# Text:  like living life --> Actual Label:  1 --> Predicted:  [1]
# Text:  i asshole i proud --> Actual Label:  1 --> Predicted:  [0]
# Text:  disgusted ugh --> Actual Label:  0 --> Predicted:  [0]
# Text:  “ good friend --> Actual Label:  1 --> Predicted:  [0]
# Text:  literally fword life --> Actual Label:  0 --> Predicted:  [0]
# Text:  woke breathing alive i blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  life getting boring ha ha ha --> Actual Label:  0 --> Predicted:  [0]
# Text:  da best --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel disappointment --> Actual Label:  0 --> Predicted:  [1]
# Text:  i finally found love life ti ame --> Actual Label:  1 --> Predicted:  [1]
# Text:  excited getting life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life😂😒😔 --> Actual Label:  0 --> Predicted:  [0]
# Text:  sad like wow --> Actual Label:  0 --> Predicted:  [1]
# Text:  stupid --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never felt sick whole life --> Actual Label:  0 --> Predicted:  [1]
# Text:  blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword smh --> Actual Label:  0 --> Predicted:  [1]
# Text:  depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  soo need change life --> Actual Label:  0 --> Predicted:  [1]
# Text:  love good --> Actual Label:  1 --> Predicted:  [0]
# Text:  oh life get comfoable --> Actual Label:  0 --> Predicted:  [0]
# Text:  one proud motherfworder --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  ew feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  laughing loud fword hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  cannot possible i amagine exactly much hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  nataleeyy sad sad life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i grown want --> Actual Label:  1 --> Predicted:  [1]
# Text:  2012 best year lifeso far --> Actual Label:  1 --> Predicted:  [1]
# Text:  soundtrack life probably best ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  i lucky i blessedyes --> Actual Label:  1 --> Predicted:  [1]
# Text:  worst attitude problems --> Actual Label:  0 --> Predicted:  [1]
# Text:  life much wanna leave world person cares dnt need u get pappaer bitch --> Actual Label:  0 --> Predicted:  [1]
# Text:  enjoying life --> Actual Label:  1 --> Predicted:  [0]
# Text:  seriously need better social life --> Actual Label:  0 --> Predicted:  [1]
# Text:  never life felt pain like --> Actual Label:  0 --> Predicted:  [0]
# Text:  everything need --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate sister hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  get ruined happiness fworden ruin best friends happiness stupid slut --> Actual Label:  0 --> Predicted:  [1]
# Text:  sorry i disappointment --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate knowing wohless --> Actual Label:  0 --> Predicted:  [0]
# Text:  i --> Actual Label:  1 --> Predicted:  [1]
# Text:  best big sister 😎 --> Actual Label:  1 --> Predicted:  [1]
# Text:  believe i living good life though face situation i living --> Actual Label:  1 --> Predicted:  [0]
# Text:  i --> Actual Label:  1 --> Predicted:  [0]
# Text:  life great i living --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring like --> Actual Label:  0 --> Predicted:  [1]
# Text:  listens i best --> Actual Label:  1 --> Predicted:  [0]
# Text:  body happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  realized life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  life sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  life --> Actual Label:  0 --> Predicted:  [0]
# Text:  true life --> Actual Label:  1 --> Predicted:  [0]
# Text:  good influence --> Actual Label:  1 --> Predicted:  [0]
# Text:  wow i soo happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  bad --> Actual Label:  0 --> Predicted:  [0]
# Text:  always get wat want --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  hey i love --> Actual Label:  1 --> Predicted:  [1]
# Text:  need change life --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel bad man --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  know nothing failure need alcohol --> Actual Label:  0 --> Predicted:  [1]
# Text:  sad help --> Actual Label:  0 --> Predicted:  [1]
# Text:  haha i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i super happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  life wrong --> Actual Label:  0 --> Predicted:  [0]
# Text:  bitch i fabulous --> Actual Label:  1 --> Predicted:  [0]
# Text:  actually pretty good picture --> Actual Label:  1 --> Predicted:  [1]
# Text:  ahahah love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  i love --> Actual Label:  1 --> Predicted:  [0]
# Text:  honestly appreciate everything everyone life --> Actual Label:  1 --> Predicted:  [0]
# Text:  best boyfriend world” things females tweet good dick --> Actual Label:  1 --> Predicted:  [1]
# Text:  life boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  know happy hahaha --> Actual Label:  1 --> Predicted:  [1]
# Text:  may perfect least i happy life --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good --> Actual Label:  0 --> Predicted:  [0]
# Text:  i proud myselfthat god --> Actual Label:  1 --> Predicted:  [1]
# Text:  one happy gal --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like bad guy --> Actual Label:  0 --> Predicted:  [1]
# Text:  love people life want people --> Actual Label:  1 --> Predicted:  [0]
# Text:  lovearieee i sad sad i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  i need damn change --> Actual Label:  0 --> Predicted:  [1]
# Text:  god blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  damn life laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  life pathetic --> Actual Label:  0 --> Predicted:  [0]
# Text:  want tell world happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life made --> Actual Label:  1 --> Predicted:  [1]
# Text:  friendshlp want live life without stress worries need rich famous want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  pay good ti ame --> Actual Label:  1 --> Predicted:  [1]
# Text:  next normal close still sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  life made --> Actual Label:  1 --> Predicted:  [1]
# Text:  amazing cannot believe life swordfest --> Actual Label:  0 --> Predicted:  [1]
# Text:  dead fword bad man --> Actual Label:  0 --> Predicted:  [0]
# Text:  ah fword life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  damn right love life live --> Actual Label:  1 --> Predicted:  [1]
# Text:  dreams coming true --> Actual Label:  1 --> Predicted:  [0]
# Text:  another love haha --> Actual Label:  1 --> Predicted:  [0]
# Text:  like ti ames --> Actual Label:  1 --> Predicted:  [1]
# Text:  i reason hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  yes i fine --> Actual Label:  1 --> Predicted:  [0]
# Text:  depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword i bored friends boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  mariakastani cannot ever happy person --> Actual Label:  0 --> Predicted:  [0]
# Text:  life --> Actual Label:  1 --> Predicted:  [0]
# Text:  want die --> Actual Label:  0 --> Predicted:  [0]
# Text:  i point life much could complain i happy got --> Actual Label:  1 --> Predicted:  [1]
# Text:  “ never happy” --> Actual Label:  0 --> Predicted:  [0]
# Text:  really fword hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  eh i huing really bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy i shaking --> Actual Label:  1 --> Predicted:  [1]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  ´ i always happy dear hope u --> Actual Label:  1 --> Predicted:  [0]
# Text:  nothing phone cause talk one sad life mine --> Actual Label:  0 --> Predicted:  [1]
# Text:  need --> Actual Label:  1 --> Predicted:  [0]
# Text:  like life live --> Actual Label:  1 --> Predicted:  [1]
# Text:  always say i fine --> Actual Label:  1 --> Predicted:  [0]
# Text:  get good feeling yeah --> Actual Label:  1 --> Predicted:  [1]
# Text:  suck --> Actual Label:  0 --> Predicted:  [0]
# Text:  dream come true --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sick life want sta somewhere new --> Actual Label:  0 --> Predicted:  [0]
# Text:  i lucky i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  rather good --> Actual Label:  1 --> Predicted:  [0]
# Text:  nothing planned --> Actual Label:  0 --> Predicted:  [0]
# Text:  keep bad girl side --> Actual Label:  0 --> Predicted:  [0]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  gone forever fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword life doe --> Actual Label:  0 --> Predicted:  [1]
# Text:  i great --> Actual Label:  1 --> Predicted:  [0]
# Text:  story life sweet --> Actual Label:  1 --> Predicted:  [1]
# Text:  think i ever disappointed entire life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sick 😔 --> Actual Label:  0 --> Predicted:  [1]
# Text:  want fword cry eyes going home hate life everything --> Actual Label:  0 --> Predicted:  [0]
# Text:  life awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  laughing loud i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate mood --> Actual Label:  0 --> Predicted:  [1]
# Text:  i’m good human --> Actual Label:  1 --> Predicted:  [1]
# Text:  thank god everything mines --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life bye twitter --> Actual Label:  0 --> Predicted:  [0]
# Text:  i i would say i pretty happy feller blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  never ever sick life --> Actual Label:  0 --> Predicted:  [1]
# Text:  dreams come true amin 4 --> Actual Label:  1 --> Predicted:  [1]
# Text:  life totally happy right noww --> Actual Label:  1 --> Predicted:  [0]
# Text:  sigh love life sucks even --> Actual Label:  0 --> Predicted:  [0]
# Text:  i pretty good --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life right noww --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel depressed empty way feel depressed way feel anything --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate hate life hate everything --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  content wit life --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life everybody --> Actual Label:  1 --> Predicted:  [1]
# Text:  best friend x --> Actual Label:  1 --> Predicted:  [0]
# Text:  damn i soo blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  2013 want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  always get want --> Actual Label:  1 --> Predicted:  [0]
# Text:  know look good --> Actual Label:  1 --> Predicted:  [1]
# Text:  must say enjoying --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  blessed highly favored --> Actual Label:  1 --> Predicted:  [0]
# Text:  i blessed god says --> Actual Label:  1 --> Predicted:  [0]
# Text:  life dawg --> Actual Label:  0 --> Predicted:  [1]
# Text:  perfect --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sorry i bad boy laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  best boyfriend ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  almost everything going planned i pleased --> Actual Label:  1 --> Predicted:  [1]
# Text:  love lifebecause jesus always --> Actual Label:  1 --> Predicted:  [1]
# Text:  fell top world --> Actual Label:  1 --> Predicted:  [0]
# Text:  hi name sarah life joke --> Actual Label:  0 --> Predicted:  [1]
# Text:  love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy life complaints pain --> Actual Label:  1 --> Predicted:  [1]
# Text:  life seriously fworded --> Actual Label:  0 --> Predicted:  [1]
# Text:  literally hate much --> Actual Label:  0 --> Predicted:  [0]
# Text:  i really always happy person --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  yup best --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life fworded get --> Actual Label:  0 --> Predicted:  [1]
# Text:  met amazing people life --> Actual Label:  1 --> Predicted:  [0]
# Text:  reievantquotes thank god blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy i --> Actual Label:  1 --> Predicted:  [1]
# Text:  god fword hate crying sleep --> Actual Label:  0 --> Predicted:  [1]
# Text:  awesome --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword life fword good --> Actual Label:  0 --> Predicted:  [1]
# Text:  really life --> Actual Label:  0 --> Predicted:  [1]
# Text:  thankin god blessing like crazy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  cares boring life --> Actual Label:  0 --> Predicted:  [1]
# Text:  want curl ball die literally --> Actual Label:  0 --> Predicted:  [1]
# Text:  life boring laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  sword life --> Actual Label:  0 --> Predicted:  [0]
# Text:  someone hear cry i dying new life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life thx asking --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel like whole life joke --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never actually drugs i happy ti ame --> Actual Label:  1 --> Predicted:  [1]
# Text:  i done feeling disgusting --> Actual Label:  0 --> Predicted:  [1]
# Text:  ahahaha nah i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  good girl sobs --> Actual Label:  1 --> Predicted:  [1]
# Text:  swear hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel good --> Actual Label:  1 --> Predicted:  [1]
# Text:  i still love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good mood --> Actual Label:  1 --> Predicted:  [1]
# Text:  pneumonia sucks 100 positive death bed better sta --> Actual Label:  0 --> Predicted:  [0]
# Text:  good one proud girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  i blessed tho --> Actual Label:  1 --> Predicted:  [0]
# Text:  good ass friends man --> Actual Label:  1 --> Predicted:  [1]
# Text:  “ take good care --> Actual Label:  1 --> Predicted:  [0]
# Text:  i thinking clearly know want --> Actual Label:  1 --> Predicted:  [1]
# Text:  smile watching cinderella story life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  oh god hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  best coworkers ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  i aloneand sad alone sad sad alone sadalone sa sa hi i alone sad sad alone --> Actual Label:  0 --> Predicted:  [1]
# Text:  life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  life --> Actual Label:  0 --> Predicted:  [1]
# Text:  man feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  i dying boredom --> Actual Label:  0 --> Predicted:  [0]
# Text:  life sucks i becoming bye --> Actual Label:  0 --> Predicted:  [0]
# Text:  i best --> Actual Label:  1 --> Predicted:  [1]
# Text:  lord dont feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  always content happens know god better choose --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life sound like freaking retard like uhm --> Actual Label:  0 --> Predicted:  [1]
# Text:  i soooo happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  jamacianlyricsyouliketoscream blessed blessed everyday life blessed wake morning --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  worst guy ever --> Actual Label:  0 --> Predicted:  [1]
# Text:  life fworded honest --> Actual Label:  0 --> Predicted:  [0]
# Text:  want happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  single want tf --> Actual Label:  1 --> Predicted:  [1]
# Text:  need nobody else --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bad boy --> Actual Label:  0 --> Predicted:  [1]
# Text:  realized happy socially --> Actual Label:  1 --> Predicted:  [1]
# Text:  see sad life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never felt disgusting life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i worst --> Actual Label:  0 --> Predicted:  [0]
# Text:  life perfect i thankful --> Actual Label:  1 --> Predicted:  [1]
# Text:  get want --> Actual Label:  1 --> Predicted:  [0]
# Text:  things calm trees get never truly satisfied happy saddest lie --> Actual Label:  0 --> Predicted:  [0]
# Text:  i got nothing --> Actual Label:  0 --> Predicted:  [1]
# Text:  omfg life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  god damn i awful --> Actual Label:  0 --> Predicted:  [0]
# Text:  wait actually hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  i --> Actual Label:  1 --> Predicted:  [1]
# Text:  ask god i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  story life left terrible --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate feeling depression --> Actual Label:  0 --> Predicted:  [0]
# Text:  i disappointed man --> Actual Label:  0 --> Predicted:  [1]
# Text:  honestly feel terrible ti ame --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy point ti ame life --> Actual Label:  1 --> Predicted:  [0]
# Text:  na nai good --> Actual Label:  1 --> Predicted:  [0]
# Text:  may perfect least i happy life --> Actual Label:  1 --> Predicted:  [1]
# Text:  best big brothers ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life 3 --> Actual Label:  1 --> Predicted:  [1]
# Text:  god stays know i blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i disappointment --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  like suck life --> Actual Label:  0 --> Predicted:  [0]
# Text:  dont think ive ever played bad life --> Actual Label:  0 --> Predicted:  [0]
# Text:  life great --> Actual Label:  1 --> Predicted:  [1]
# Text:  life boring hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  feel like i top world love --> Actual Label:  1 --> Predicted:  [0]
# Text:  right stressed --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate fword teenage life --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life guy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i proud cannot explain i --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate late --> Actual Label:  0 --> Predicted:  [0]
# Text:  bestest friends ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  best friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  life never felt complete --> Actual Label:  1 --> Predicted:  [1]
# Text:  bunny kid melted melted life awesome --> Actual Label:  1 --> Predicted:  [1]
# Text:  made many stupid decisions life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i still happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  thank god blessing another day --> Actual Label:  1 --> Predicted:  [1]
# Text:  i glad achieved ai --> Actual Label:  1 --> Predicted:  [0]
# Text:  love find everything --> Actual Label:  1 --> Predicted:  [1]
# Text:  sick fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  think made worst mistake life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword fword loving --> Actual Label:  1 --> Predicted:  [1]
# Text:  incredibly blessed thankful everyone life god great i i would lost without hi --> Actual Label:  1 --> Predicted:  [0]
# Text:  ti ames like get think wish life different --> Actual Label:  0 --> Predicted:  [0]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i really happy girl --> Actual Label:  1 --> Predicted:  [0]
# Text:  i none --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bloody brilliant --> Actual Label:  1 --> Predicted:  [1]
# Text:  jus want one thing happy much ask --> Actual Label:  0 --> Predicted:  [1]
# Text:  laughing loud know life lame --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  life way good true --> Actual Label:  1 --> Predicted:  [1]
# Text:  whole life fword lie --> Actual Label:  0 --> Predicted:  [1]
# Text:  nothing failure always always constantly let everyone never make anyone happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  wrong life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i real good mood --> Actual Label:  1 --> Predicted:  [1]
# Text:  mywishin2013 want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  still feeling sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  use fast forward swordty life --> Actual Label:  0 --> Predicted:  [1]
# Text:  alot friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  life pretty boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  ew hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  got fired ft job 2 days ago miss friends life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life great yea ups downs great friends family woh end --> Actual Label:  1 --> Predicted:  [1]
# Text:  loving good wife --> Actual Label:  1 --> Predicted:  [1]
# Text:  oh feel good --> Actual Label:  1 --> Predicted:  [1]
# Text:  dang i super sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy life --> Actual Label:  1 --> Predicted:  [1]
# Text:  mywishin2013 happy want --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword life man --> Actual Label:  0 --> Predicted:  [0]
# Text:  seriously worst mood swings ever one minute i like next i like soemotional hatemylife --> Actual Label:  0 --> Predicted:  [1]
# Text:  haha i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  always one thing another i tired unhappy --> Actual Label:  0 --> Predicted:  [1]
# Text:  sitting around cause life --> Actual Label:  0 --> Predicted:  [0]
# Text:  sorry i fword --> Actual Label:  0 --> Predicted:  [1]
# Text:  making life living hell --> Actual Label:  0 --> Predicted:  [1]
# Text:  swear weirdest sword happens --> Actual Label:  0 --> Predicted:  [1]
# Text:  typicalbilkey hate life everything sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  i horrible person --> Actual Label:  0 --> Predicted:  [0]
# Text:  i truly blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  whatever want --> Actual Label:  1 --> Predicted:  [1]
# Text:  i afraid losing long give ti ame try i fine --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy happy together happy 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy though lifes good --> Actual Label:  1 --> Predicted:  [0]
# Text:  ey ey uu stupid brother --> Actual Label:  0 --> Predicted:  [0]
# Text:  say happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  happy saddest lie --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [0]
# Text:  i truly blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  cause i perfect --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love clothes love love love --> Actual Label:  1 --> Predicted:  [0]
# Text:  sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  ‚äú i --> Actual Label:  1 --> Predicted:  [1]
# Text:  really truly hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  hahahah life sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  new changes life i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life dream --> Actual Label:  1 --> Predicted:  [1]
# Text:  thank lord giving good life live appreciated always --> Actual Label:  1 --> Predicted:  [1]
# Text:  good boy p --> Actual Label:  1 --> Predicted:  [1]
# Text:  i totally love mine 3 amazing --> Actual Label:  1 --> Predicted:  [0]
# Text:  everything hus want die --> Actual Label:  0 --> Predicted:  [1]
# Text:  i beautiful --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life point would change nothin --> Actual Label:  1 --> Predicted:  [1]
# Text:  i beyond blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy person know --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword life max --> Actual Label:  0 --> Predicted:  [1]
# Text:  yeah laughing loud worst headache --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  500aday hate embarrassing --> Actual Label:  0 --> Predicted:  [0]
# Text:  worst headache everrr😭 --> Actual Label:  0 --> Predicted:  [1]
# Text:  life becoming boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  life hard sho need drink --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life though --> Actual Label:  1 --> Predicted:  [0]
# Text:  know i singing i happy i happy happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  get depressed everyday --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel bad okay man --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  i thankful life thank god love --> Actual Label:  1 --> Predicted:  [1]
# Text:  «christoosteezy i depressed ass oh god i depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy u dont even know --> Actual Label:  1 --> Predicted:  [1]
# Text:  single life boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  best play tho --> Actual Label:  1 --> Predicted:  [0]
# Text:  ha ha love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  best friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  everyone ti ame hate life ti ame never goes away ever --> Actual Label:  0 --> Predicted:  [0]
# Text:  happy prefer --> Actual Label:  1 --> Predicted:  [1]
# Text:  i single happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  life never ending sick joke --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  everyday wonderful day wake live life knowing best family friends 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  i worry wa hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  life i loving living --> Actual Label:  1 --> Predicted:  [1]
# Text:  everything like depressing bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  smile i blessed 💙 life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life awkward moments --> Actual Label:  0 --> Predicted:  [0]
# Text:  i nothing huing --> Actual Label:  0 --> Predicted:  [0]
# Text:  head i good life --> Actual Label:  1 --> Predicted:  [1]
# Text:  guys i love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i accepted i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  blessed stressed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i great --> Actual Label:  1 --> Predicted:  [0]
# Text:  boring life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good man --> Actual Label:  1 --> Predicted:  [1]
# Text:  i bad person --> Actual Label:  0 --> Predicted:  [1]
# Text:  fun --> Actual Label:  1 --> Predicted:  [0]
# Text:  i unhappy --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sure fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  i i proud --> Actual Label:  1 --> Predicted:  [1]
# Text:  life soooo --> Actual Label:  0 --> Predicted:  [1]
# Text:  terrible person --> Actual Label:  0 --> Predicted:  [0]
# Text:  believe worst i ammune system ever --> Actual Label:  0 --> Predicted:  [0]
# Text:  tired much sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy say everything could possibly want life would change thing --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  love cheh haha --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like disappointment --> Actual Label:  0 --> Predicted:  [1]
# Text:  i really good --> Actual Label:  1 --> Predicted:  [0]
# Text:  buy anything want cuz got check --> Actual Label:  1 --> Predicted:  [0]
# Text:  buy anything want cuz got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good u --> Actual Label:  1 --> Predicted:  [0]
# Text:  someti ames want able feel happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  boy really hate everything way look laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  buy anything want got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  ever hate hate everyday --> Actual Label:  0 --> Predicted:  [0]
# Text:  count every day blessing case i blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life mom --> Actual Label:  0 --> Predicted:  [1]
# Text:  fword whole life tell --> Actual Label:  0 --> Predicted:  [0]
# Text:  life laughing loud --> Actual Label:  0 --> Predicted:  [0]
# Text:  love good --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  i n love --> Actual Label:  1 --> Predicted:  [0]
# Text:  love way --> Actual Label:  1 --> Predicted:  [0]
# Text:  really hate life ugh 😡 😡 --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  god continues bless --> Actual Label:  1 --> Predicted:  [0]
# Text:  jesus love --> Actual Label:  1 --> Predicted:  [0]
# Text:  would change thing --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life love even hours 5 --> Actual Label:  1 --> Predicted:  [1]
# Text:  woman 😉 --> Actual Label:  1 --> Predicted:  [0]
# Text:  probably knows i bad boy --> Actual Label:  0 --> Predicted:  [1]
# Text:  best sisters ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  sup i beautiful --> Actual Label:  1 --> Predicted:  [1]
# Text:  god blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  i stressed --> Actual Label:  0 --> Predicted:  [0]
# Text:  bc i moment i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  glad real friends lmao --> Actual Label:  1 --> Predicted:  [1]
# Text:  yep i miserable --> Actual Label:  0 --> Predicted:  [1]
# Text:  i angry sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear stressed life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i definitely good --> Actual Label:  0 --> Predicted:  [1]
# Text:  i one good --> Actual Label:  1 --> Predicted:  [0]
# Text:  i bit sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  i breathing ✔ i alive ✔ i blessed ✔ amen --> Actual Label:  1 --> Predicted:  [1]
# Text:  love content happyhappyhappy --> Actual Label:  1 --> Predicted:  [0]
# Text:  hahaha yeah oh god i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  anything want cause got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love üòç --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring feel 100 years old --> Actual Label:  0 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  tvd life love --> Actual Label:  1 --> Predicted:  [1]
# Text:  i beautiful 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  yeah got life --> Actual Label:  0 --> Predicted:  [1]
# Text:  idk maybe i depressed person --> Actual Label:  0 --> Predicted:  [0]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  want fun life --> Actual Label:  1 --> Predicted:  [0]
# Text:  god words cannot describe much love thanks blessing life everything --> Actual Label:  1 --> Predicted:  [1]
# Text:  great life --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  think i depressed --> Actual Label:  0 --> Predicted:  [0]
# Text:  fword always sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  man living good life --> Actual Label:  1 --> Predicted:  [1]
# Text:  hus knowing i shall i never happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  dancer2lm srsly life boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  honestly someone trade i sick swordty life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate sensitive emotional --> Actual Label:  0 --> Predicted:  [1]
# Text:  anything want get --> Actual Label:  1 --> Predicted:  [0]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  made pissing idk man life --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate life bye --> Actual Label:  0 --> Predicted:  [1]
# Text:  novazarvhancov si wooo p sekarang happy day --> Actual Label:  1 --> Predicted:  [0]
# Text:  made feel proud --> Actual Label:  1 --> Predicted:  [1]
# Text:  got dreams got --> Actual Label:  1 --> Predicted:  [1]
# Text:  ross i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  life good nowadays --> Actual Label:  1 --> Predicted:  [1]
# Text:  keeping locked honestly best thing i done life i i would say i perfect --> Actual Label:  1 --> Predicted:  [0]
# Text:  damnitstrue thanks god blessing deserve --> Actual Label:  1 --> Predicted:  [0]
# Text:  life live pretty --> Actual Label:  1 --> Predicted:  [1]
# Text:  love love love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  good news --> Actual Label:  1 --> Predicted:  [0]
# Text:  supposed happy i surrounded assholes --> Actual Label:  0 --> Predicted:  [1]
# Text:  yes i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  got sword goin life --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life matter complicated might know everything okay end --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love --> Actual Label:  1 --> Predicted:  [0]
# Text:  let us say i terrible person --> Actual Label:  0 --> Predicted:  [0]
# Text:  fword life dude omfg --> Actual Label:  0 --> Predicted:  [0]
# Text:  pocket full sunshine --> Actual Label:  1 --> Predicted:  [1]
# Text:  i makes best --> Actual Label:  1 --> Predicted:  [0]
# Text:  mywishin2013 happy life happy kid like --> Actual Label:  1 --> Predicted:  [0]
# Text:  sorry i bad person --> Actual Label:  0 --> Predicted:  [0]
# Text:  i good mood --> Actual Label:  1 --> Predicted:  [0]
# Text:  lmfaoo life awesome tglicks lmfao oh god made laugh --> Actual Label:  1 --> Predicted:  [0]
# Text:  i much fun --> Actual Label:  1 --> Predicted:  [0]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i also good --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  getting hu life --> Actual Label:  0 --> Predicted:  [0]
# Text:  things like --> Actual Label:  1 --> Predicted:  [0]
# Text:  uh kinda love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  ohmigod ohmigod love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  long god everything need --> Actual Label:  1 --> Predicted:  [0]
# Text:  jk actually life --> Actual Label:  0 --> Predicted:  [0]
# Text:  seriously hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  watch dreams come true --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good person hate --> Actual Label:  1 --> Predicted:  [0]
# Text:  life happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  oh god found love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i always love --> Actual Label:  1 --> Predicted:  [1]
# Text:  another great morning ahh love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  thank god every blessing death love everything everything live learn everyday --> Actual Label:  1 --> Predicted:  [0]
# Text:  i gotten better i proud much i --> Actual Label:  1 --> Predicted:  [0]
# Text:  whole life feels like dream --> Actual Label:  1 --> Predicted:  [1]
# Text:  morning feel blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  happy mood laughing loud --> Actual Label:  1 --> Predicted:  [1]
# Text:  love bad girl look --> Actual Label:  0 --> Predicted:  [0]
# Text:  god good blessed everything life oppounities li --> Actual Label:  1 --> Predicted:  [0]
# Text:  laughing loud i sorry love --> Actual Label:  1 --> Predicted:  [1]
# Text:  blasting call maybe campus ti ame love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  thank god blessing life everyday --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate life really going nothing compared pain depression --> Actual Label:  0 --> Predicted:  [0]
# Text:  point life know less faith people general --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never cramps long life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  god good blessed” --> Actual Label:  1 --> Predicted:  [0]
# Text:  look last years life i great --> Actual Label:  1 --> Predicted:  [1]
# Text:  happy prefer --> Actual Label:  1 --> Predicted:  [1]
# Text:  i --> Actual Label:  1 --> Predicted:  [1]
# Text:  na i feeling blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  best girlfriend ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  love way --> Actual Label:  1 --> Predicted:  [0]
# Text:  complaints i great --> Actual Label:  1 --> Predicted:  [0]
# Text:  reiatable dear 2013 want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  wish everything different --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  dont feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  love --> Actual Label:  1 --> Predicted:  [1]
# Text:  man i good üëç --> Actual Label:  1 --> Predicted:  [0]
# Text:  fml i uncomfoable --> Actual Label:  0 --> Predicted:  [0]
# Text:  always get screwed someway somehow life going good something happen mess --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear worst luck --> Actual Label:  0 --> Predicted:  [1]
# Text:  best friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  nye cannot believe happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  missed 746 hate life fword fword fword --> Actual Label:  0 --> Predicted:  [0]
# Text:  loving life people --> Actual Label:  1 --> Predicted:  [1]
# Text:  need better life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  idea anything life great --> Actual Label:  1 --> Predicted:  [1]
# Text:  sure dont feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [1]
# Text:  wish happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life really hate --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate everything --> Actual Label:  0 --> Predicted:  [0]
# Text:  nahh i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  tired feeling like want happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  dont feel good trigger happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel man --> Actual Label:  0 --> Predicted:  [1]
# Text:  awesome --> Actual Label:  1 --> Predicted:  [1]
# Text:  really want happy --> Actual Label:  0 --> Predicted:  [0]
# Text:  could blame anyone hating since hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  lmao love ahh c --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good life clearly --> Actual Label:  0 --> Predicted:  [0]
# Text:  i feelin love --> Actual Label:  0 --> Predicted:  [0]
# Text:  nan --> Actual Label:  1 --> Predicted:  [1]
# Text:  hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  unhappy --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate much hate --> Actual Label:  0 --> Predicted:  [1]
# Text:  love life man --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good girl --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate --> Actual Label:  0 --> Predicted:  [0]
# Text:  hope everyones happy life miserable --> Actual Label:  0 --> Predicted:  [1]
# Text:  love plans --> Actual Label:  1 --> Predicted:  [1]
# Text:  really hate i --> Actual Label:  0 --> Predicted:  [0]
# Text:  worst luck --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sad huing --> Actual Label:  0 --> Predicted:  [0]
# Text:  eww i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  couple weeks 2013 i already stressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  wanna die hate life everyone wrong --> Actual Label:  0 --> Predicted:  [1]
# Text:  laughing loud girl miserable --> Actual Label:  0 --> Predicted:  [0]
# Text:  man suck life --> Actual Label:  0 --> Predicted:  [0]
# Text:  get jealous anything --> Actual Label:  0 --> Predicted:  [1]
# Text:  fun --> Actual Label:  1 --> Predicted:  [0]
# Text:  truely happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  life turned upside --> Actual Label:  0 --> Predicted:  [1]
# Text:  ‚äú love life äù --> Actual Label:  1 --> Predicted:  [0]
# Text:  cause life --> Actual Label:  0 --> Predicted:  [0]
# Text:  idea want --> Actual Label:  0 --> Predicted:  [1]
# Text:  best dog lt --> Actual Label:  1 --> Predicted:  [0]
# Text:  i feeling good --> Actual Label:  0 --> Predicted:  [1]
# Text:  stay bored cuz life --> Actual Label:  0 --> Predicted:  [1]
# Text:  andrewlaa hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  god i dull --> Actual Label:  0 --> Predicted:  [0]
# Text:  worst headache --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel damn good --> Actual Label:  1 --> Predicted:  [0]
# Text:  long day proud --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword life --> Actual Label:  1 --> Predicted:  [0]
# Text:  life wonderful minus bs --> Actual Label:  1 --> Predicted:  [1]
# Text:  want --> Actual Label:  0 --> Predicted:  [0]
# Text:  lord i --> Actual Label:  1 --> Predicted:  [1]
# Text:  nah i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  cause i ugly --> Actual Label:  0 --> Predicted:  [0]
# ...
# Text:  wow hate life thx 2 u weirdalexis --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy ‚ò∫ --> Actual Label:  1 --> Predicted:  [1]
# Text:  least sword --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good 2012 --> Actual Label:  1 --> Predicted:  [0]
# Text:  worked i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i bad person honest --> Actual Label:  0 --> Predicted:  [1]
# Text:  need people life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i blessed much --> Actual Label:  1 --> Predicted:  [1]
# Text:  live sad lifelaughing loud nah kidding life freakin great dude --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good teacher --> Actual Label:  1 --> Predicted:  [0]
# Text:  hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  good i pretty good --> Actual Label:  1 --> Predicted:  [0]
# Text:  life sword hole wow --> Actual Label:  0 --> Predicted:  [0]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [1]
# Text:  i damn comfy --> Actual Label:  1 --> Predicted:  [0]
# Text:  i blessed 🙏 --> Actual Label:  1 --> Predicted:  [1]
# Text:  need head change --> Actual Label:  0 --> Predicted:  [0]
# Text:  anda wants yes life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  life house sucks --> Actual Label:  0 --> Predicted:  [1]
# Text:  know satisfied --> Actual Label:  1 --> Predicted:  [1]
# Text:  i blessed --> Actual Label:  1 --> Predicted:  [0]
# Text:  everything need --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy life anymore --> Actual Label:  0 --> Predicted:  [0]
# Text:  love trust 2 people need --> Actual Label:  1 --> Predicted:  [1]
# Text:  i actually happy i going tweet happy things --> Actual Label:  1 --> Predicted:  [0]
# Text:  i loving life --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good wee man --> Actual Label:  1 --> Predicted:  [0]
# Text:  want happy used --> Actual Label:  0 --> Predicted:  [1]
# Text:  wish could life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i sad wtf --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear nothing life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bad girl --> Actual Label:  0 --> Predicted:  [1]
# Text:  i tired people thinking i bad person --> Actual Label:  0 --> Predicted:  [1]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  enjoying new life form4 --> Actual Label:  1 --> Predicted:  [0]
# Text:  wow life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  nope i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  fwordin love life 2012 damn good --> Actual Label:  1 --> Predicted:  [1]
# Text:  i sadi really really sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  love feeling finally happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  think i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  real talk really like --> Actual Label:  1 --> Predicted:  [1]
# Text:  i pretty good --> Actual Label:  1 --> Predicted:  [1]
# Text:  life sucks bad wow --> Actual Label:  0 --> Predicted:  [0]
# Text:  love i --> Actual Label:  1 --> Predicted:  [0]
# Text:  yes i fine --> Actual Label:  1 --> Predicted:  [1]
# Text:  mother mary swear want change --> Actual Label:  0 --> Predicted:  [1]
# Text:  tired everything want die --> Actual Label:  0 --> Predicted:  [1]
# Text:  really hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  needs met i ammediately --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good mood --> Actual Label:  1 --> Predicted:  [1]
# Text:  i disappointed cant disappointed --> Actual Label:  0 --> Predicted:  [0]
# Text:  damn fword life --> Actual Label:  0 --> Predicted:  [0]
# Text:  i amazing --> Actual Label:  1 --> Predicted:  [0]
# Text:  misery --> Actual Label:  0 --> Predicted:  [1]
# Text:  best friends ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  actually hate x --> Actual Label:  0 --> Predicted:  [0]
# Text:  crazy night many friends --> Actual Label:  1 --> Predicted:  [0]
# Text:  drinking watching positive turning --> Actual Label:  1 --> Predicted:  [0]
# Text:  life terrible --> Actual Label:  0 --> Predicted:  [0]
# Text:  life sucks --> Actual Label:  0 --> Predicted:  [0]
# Text:  glad god blessed girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  life great nothing else could ask --> Actual Label:  1 --> Predicted:  [0]
# Text:  best gf ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  dont know people seem love much hate bloody much --> Actual Label:  0 --> Predicted:  [1]
# Text:  blessed every day life blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  i falling love --> Actual Label:  1 --> Predicted:  [0]
# Text:  officially hate life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life beautiful --> Actual Label:  1 --> Predicted:  [0]
# Text:  i living pretty good life --> Actual Label:  1 --> Predicted:  [0]
# Text:  fword life laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  pretty boring life --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel getting miserable --> Actual Label:  0 --> Predicted:  [0]
# Text:  best actually --> Actual Label:  1 --> Predicted:  [0]
# Text:  none --> Actual Label:  0 --> Predicted:  [0]
# Text:  life full empty promises broken dreams --> Actual Label:  0 --> Predicted:  [0]
# Text:  i hungry sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life people --> Actual Label:  1 --> Predicted:  [0]
# Text:  feel like good person --> Actual Label:  1 --> Predicted:  [0]
# Text:  want much --> Actual Label:  0 --> Predicted:  [0]
# Text:  hahaha love life --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy life rn --> Actual Label:  1 --> Predicted:  [0]
# Text:  depressed tt --> Actual Label:  0 --> Predicted:  [0]
# Text:  know i sitting hating life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life boring really hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good girl bad habits --> Actual Label:  1 --> Predicted:  [1]
# Text:  place i boring --> Actual Label:  0 --> Predicted:  [0]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  want change background --> Actual Label:  0 --> Predicted:  [1]
# Text:  really dont feel good --> Actual Label:  0 --> Predicted:  [1]
# Text:  life fword mistake --> Actual Label:  0 --> Predicted:  [1]
# Text:  life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [0]
# Text:  trolaughing loud sobs good girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  get sword done --> Actual Label:  0 --> Predicted:  [0]
# Text:  staing hate life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate college messed life --> Actual Label:  0 --> Predicted:  [1]
# Text:  like keep --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good enjoying life --> Actual Label:  1 --> Predicted:  [1]
# Text:  everything right want 2013 life good 20 old cannot complain --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel like --> Actual Label:  1 --> Predicted:  [0]
# Text:  love life fword bull sword --> Actual Label:  1 --> Predicted:  [0]
# Text:  i sweet --> Actual Label:  1 --> Predicted:  [1]
# Text:  i good i --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  check twitter every 8 life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sad --> Actual Label:  0 --> Predicted:  [0]
# Text:  omfg love --> Actual Label:  1 --> Predicted:  [1]
# Text:  suck life --> Actual Label:  0 --> Predicted:  [0]
# Text:  want die --> Actual Label:  0 --> Predicted:  [0]
# Text:  world awesome show world amazing life --> Actual Label:  1 --> Predicted:  [1]
# Text:  really happy atm --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy anymore --> Actual Label:  0 --> Predicted:  [1]
# Text:  cannot stop crying hate life family much --> Actual Label:  0 --> Predicted:  [1]
# Text:  i obsessed kno love --> Actual Label:  1 --> Predicted:  [0]
# Text:  sad life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i always depressed mood ffs --> Actual Label:  0 --> Predicted:  [0]
# Text:  feel blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  lalalalala life bitch likes target make everything good ti ames worse thanks life lovely lalalalala --> Actual Label:  0 --> Predicted:  [0]
# Text:  living good lifei love hermit life style --> Actual Label:  1 --> Predicted:  [1]
# Text:  know always seem fword things life --> Actual Label:  0 --> Predicted:  [1]
# Text:  sorry sir love --> Actual Label:  1 --> Predicted:  [1]
# Text:  pay like enjoy life --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life seriously --> Actual Label:  1 --> Predicted:  [1]
# Text:  worst headache --> Actual Label:  0 --> Predicted:  [1]
# Text:  i never felt sick life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i good --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  life boring --> Actual Label:  0 --> Predicted:  [1]
# Text:  reellcute loving single life tho --> Actual Label:  1 --> Predicted:  [0]
# Text:  i generally good person --> Actual Label:  1 --> Predicted:  [1]
# Text:  wish happy life --> Actual Label:  0 --> Predicted:  [0]
# Text:  live pretty fabulous life --> Actual Label:  1 --> Predicted:  [0]
# Text:  want happy --> Actual Label:  0 --> Predicted:  [1]
# Text:  one life enjoy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i going love --> Actual Label:  1 --> Predicted:  [0]
# Text:  i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  i got best friends ever --> Actual Label:  1 --> Predicted:  [0]
# Text:  i stressed ridiculous --> Actual Label:  0 --> Predicted:  [1]
# Text:  finally enjoy college life --> Actual Label:  1 --> Predicted:  [1]
# Text:  fword man life --> Actual Label:  0 --> Predicted:  [0]
# Text:  oh god best dad ever ☺ --> Actual Label:  1 --> Predicted:  [1]
# Text:  wish suck --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate fword life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life --> Actual Label:  0 --> Predicted:  [1]
# Text:  life ti ame sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  honestly love life thanks --> Actual Label:  1 --> Predicted:  [1]
# Text:  i even mad anymore i calm content --> Actual Label:  0 --> Predicted:  [1]
# Text:  i bored hate life even left house week go gym --> Actual Label:  0 --> Predicted:  [1]
# Text:  changed life love 3 --> Actual Label:  1 --> Predicted:  [1]
# Text:  i full sword --> Actual Label:  0 --> Predicted:  [0]
# Text:  dude life love --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel good trigga happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i way tired life --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel boredom --> Actual Label:  0 --> Predicted:  [0]
# Text:  life fword sucks ass --> Actual Label:  0 --> Predicted:  [1]
# Text:  someone save i boredom --> Actual Label:  0 --> Predicted:  [0]
# Text:  want --> Actual Label:  0 --> Predicted:  [0]
# Text:  worst nightmares --> Actual Label:  0 --> Predicted:  [1]
# Text:  want --> Actual Label:  1 --> Predicted:  [1]
# Text:  really happy life --> Actual Label:  0 --> Predicted:  [0]
# Text:  hate much love hi --> Actual Label:  0 --> Predicted:  [1]
# Text:  awesome --> Actual Label:  1 --> Predicted:  [1]
# Text:  good feeling things --> Actual Label:  1 --> Predicted:  [0]
# Text:  life 3 --> Actual Label:  1 --> Predicted:  [0]
# Text:  make life complete --> Actual Label:  1 --> Predicted:  [0]
# Text:  happy amazing people life --> Actual Label:  1 --> Predicted:  [1]
# Text:  cares life hell laughing loud --> Actual Label:  0 --> Predicted:  [1]
# Text:  i already love --> Actual Label:  1 --> Predicted:  [0]
# Text:  mean i pretty fword awesome --> Actual Label:  1 --> Predicted:  [1]
# Text:  want happy use --> Actual Label:  0 --> Predicted:  [0]
# Text:  ijustdoit i happy life complete call sweet thang --> Actual Label:  1 --> Predicted:  [1]
# Text:  guess i depressed --> Actual Label:  0 --> Predicted:  [1]
# Text:  life sooo fworded --> Actual Label:  0 --> Predicted:  [0]
# Text:  life boring oh god --> Actual Label:  0 --> Predicted:  [0]
# Text:  life ass --> Actual Label:  0 --> Predicted:  [0]
# Text:  swear sword happens --> Actual Label:  0 --> Predicted:  [1]
# Text:  life big borring --> Actual Label:  0 --> Predicted:  [1]
# Text:  nahh i good --> Actual Label:  1 --> Predicted:  [0]
# Text:  life i living nothing blessing --> Actual Label:  1 --> Predicted:  [1]
# Text:  laughing loud life --> Actual Label:  0 --> Predicted:  [1]
# Text:  i sick ‾ʃƪ‾ --> Actual Label:  0 --> Predicted:  [0]
# Text:  loving life regardless tries stop p --> Actual Label:  1 --> Predicted:  [1]
# Text:  could never right --> Actual Label:  0 --> Predicted:  [1]
# Text:  life could better sisters fword amazing --> Actual Label:  1 --> Predicted:  [0]
# Text:  cannot believe sword called life --> Actual Label:  0 --> Predicted:  [0]
# Text:  good friends --> Actual Label:  1 --> Predicted:  [1]
# Text:  something want within reach --> Actual Label:  0 --> Predicted:  [0]
# Text:  honestly sword oh god literally --> Actual Label:  0 --> Predicted:  [1]
# Text:  i getting boring life hm hm --> Actual Label:  0 --> Predicted:  [0]
# Text:  i happy girl‚ô• --> Actual Label:  1 --> Predicted:  [0]
# Text:  happy finally found good man --> Actual Label:  1 --> Predicted:  [0]
# Text:  true life cannot sex sad smh --> Actual Label:  0 --> Predicted:  [0]
# Text:  kinda love young life --> Actual Label:  1 --> Predicted:  [1]
# Text:  damn best boyfriend --> Actual Label:  1 --> Predicted:  [1]
# Text:  best major ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  good job --> Actual Label:  1 --> Predicted:  [0]
# Text:  want happy let please --> Actual Label:  0 --> Predicted:  [0]
# Text:  love looking --> Actual Label:  1 --> Predicted:  [1]
# Text:  okay i fine --> Actual Label:  1 --> Predicted:  [0]
# Text:  life good complain much --> Actual Label:  1 --> Predicted:  [1]
# Text:  good life whole life long looked back life whole life gone go wrong --> Actual Label:  0 --> Predicted:  [1]
# Text:  day leave everything going great --> Actual Label:  1 --> Predicted:  [0]
# Text:  awesome i quite happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  life bad --> Actual Label:  0 --> Predicted:  [1]
# Text:  feel like disappointment everyone --> Actual Label:  0 --> Predicted:  [0]
# Text:  i ugly --> Actual Label:  0 --> Predicted:  [0]
# Text:  life lie --> Actual Label:  0 --> Predicted:  [0]
# Text:  forgive i flawed --> Actual Label:  0 --> Predicted:  [0]
# Text:  i i feeling sad --> Actual Label:  0 --> Predicted:  [1]
# Text:  bestest friends ever --> Actual Label:  1 --> Predicted:  [1]
# Text:  themarcusdesion could easily complain things wrong life much good need --> Actual Label:  1 --> Predicted:  [1]
# Text:  love life mess --> Actual Label:  0 --> Predicted:  [0]
# Text:  found life good happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  i love jesse pitch perfect --> Actual Label:  1 --> Predicted:  [1]
# Text:  would trade life --> Actual Label:  1 --> Predicted:  [0]
# Text:  go i triple blessed --> Actual Label:  1 --> Predicted:  [1]
# Text:  know made right decision could happier --> Actual Label:  1 --> Predicted:  [1]
# Text:  enjoy life --> Actual Label:  1 --> Predicted:  [1]
# Text:  one happy girl tonite --> Actual Label:  1 --> Predicted:  [1]
# Text:  horrible life --> Actual Label:  0 --> Predicted:  [1]
# Text:  sad ti ame --> Actual Label:  0 --> Predicted:  [1]
# Text:  hate looking mirror --> Actual Label:  0 --> Predicted:  [0]
# Text:  go like little depression moods even know depression --> Actual Label:  0 --> Predicted:  [1]
# Text:  know i perfect --> Actual Label:  1 --> Predicted:  [1]
# Text:  i happy --> Actual Label:  1 --> Predicted:  [1]
# Text:  none --> Actual Label:  0 --> Predicted:  [1]
# Text:  happy girl --> Actual Label:  1 --> Predicted:  [1]
# Text:  feel good --> Actual Label:  0 --> Predicted:  [0]
# Text:  anything want bc got check --> Actual Label:  1 --> Predicted:  [1]
# Text:  much love life --> Actual Label:  1 --> Predicted:  [0]
# Text:  bitch want --> Actual Label:  1 --> Predicted:  [1]
# Text:  hi i good --> Actual Label:  1 --> Predicted:  [0]

# %% [markdown]
# ### Predict on Unseen Data

# %%
nd1 = ["i am the happiest person in this world"]
nd2 = ['i am excited']
nd3 = ['i would not change the past if I could']
nd4 = ['i get everything i want']
nd5 = ['everyday of my life is a celebration']
nd6 = ['my life is blessed']
nd7 = ['i feel complete']
nd8 = ['thank you god']
nd9 = ['i love my family']
nd10 = ['i am in a great mood']
nd11 = ['i never feel sad']   
nd12 = ['i hate chocolate']         

nd1pad = vect.texts_to_sequences(nd1)
nd1pad = pad_sequences(nd1pad, maxlen=9, padding='post')
prednd1 = model.predict_classes(nd1pad).item()
#prednd1a = (model.predict(nd1pad) > 0.5).astype("int32")
#prednd1c = np.argmax(prednd1)
#print(prednd1a, prednd1b, prednd1c)


nd2pad = vect.texts_to_sequences(nd2)
nd2pad = pad_sequences(nd2pad, maxlen=3, padding='post')
prednd2 = model.predict_classes(nd2pad).item()


nd3pad = vect.texts_to_sequences(nd3)
nd3pad = pad_sequences(nd3pad, maxlen=9, padding='post')
prednd3 = model.predict_classes(nd3pad).item()

nd4pad = vect.texts_to_sequences(nd4)
nd4pad = pad_sequences(nd4pad, maxlen=5, padding='post')
prednd4 = model.predict_classes(nd4pad).item()

nd5pad = vect.texts_to_sequences(nd5)
nd5pad = pad_sequences(nd5pad, maxlen=7, padding='post')
prednd5 = model.predict_classes(nd5pad).item()

nd6pad = vect.texts_to_sequences(nd6)
nd6pad = pad_sequences(nd6pad, maxlen=4, padding='post')
prednd6 = model.predict_classes(nd6pad).item()


nd7pad = vect.texts_to_sequences(nd7)
nd7pad = pad_sequences(nd7pad, maxlen=3, padding='post')
prednd7 = model.predict_classes(nd7pad).item()

nd8pad = vect.texts_to_sequences(nd8)
nd8pad = pad_sequences(nd8pad, maxlen=3, padding='post')
prednd8 = model.predict_classes(nd8pad).item()

nd9pad = vect.texts_to_sequences(nd9)
nd9pad = pad_sequences(nd9pad, maxlen=4, padding='post')
prednd9 = model.predict_classes(nd9pad).item()

nd10pad = vect.texts_to_sequences(nd10)
nd10pad = pad_sequences(nd10pad, maxlen=8, padding='post')
prednd10 = model.predict_classes(nd10pad).item()

nd11pad = vect.texts_to_sequences(nd11)
nd11pad = pad_sequences(nd11pad, maxlen=4, padding='post')
prednd11 = model.predict_classes(nd11pad).item()

nd12pad = vect.texts_to_sequences(nd12)
nd12pad = pad_sequences(nd12pad, maxlen=3, padding='post')
prednd12 = model.predict_classes(nd12pad).item()
#prednd12 = (model.predict(nd12pad) > 0.5).astype("int32")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 9).
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print("Text: ",nd1, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd1)
print("Text: ",nd2, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd2)
print("Text: ",nd3, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd3)
print("Text: ",nd4, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd4)
print("Text: ",nd5, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd5)
print("Text: ",nd6, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd6)
print("Text: ",nd7, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd7)
print("Text: ",nd8, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd8)
print("Text: ",nd9, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd9)
print("Text: ",nd10, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd10)
print("Text: ",nd11, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd11)
print("Text: ",nd12, "-->", "Actual Label: ", "1", "-->", "Predicted: ", prednd12)
# Out:
# Text:  ['i am the happiest person in this world'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i am excited'] --> Actual Label:  1 --> Predicted:  0
# Text:  ['i would not change the past if I could'] --> Actual Label:  1 --> Predicted:  0
# Text:  ['i get everything i want'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['everyday of my life is a celebration'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['my life is blessed'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i feel complete'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['thank you god'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i love my family'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i am in a great mood'] --> Actual Label:  1 --> Predicted:  1
# Text:  ['i never feel sad'] --> Actual Label:  1 --> Predicted:  0
# Text:  ['i hate chocolate'] --> Actual Label:  1 --> Predicted:  0

# %%
d1 = ['i have lost in life']
d2 = ['why do i have to be sad']
d3 = ['i have never been so disappointed in life']
d4 = ['i feel like crying'] 
d5 = ['i hate the world'] 
d6 = ['why is everything so hard'] 
d7 = ['i feel miserable']
d8 = ['i live in a terrible place'] 
d9 = ['i cry all day'] 
d10 = ['i am not lucky nor blessed']
d11 = ['nobody loves me']
d12 = ['i am unlucky']         

d1pad = vect.texts_to_sequences(d1)
d1pad = pad_sequences(nd1pad, maxlen=6, padding='post')
#prednd1 = (model.predict(nd1pad) > 0.5).astype("int32")
predd1 = model.predict_classes(d1pad).item()


d2pad = vect.texts_to_sequences(d2)
d2pad = pad_sequences(d2pad, maxlen=7, padding='post')
predd2 = model.predict_classes(d2pad).item()

d3pad = vect.texts_to_sequences(d3)
d3pad = pad_sequences(d3pad, maxlen=8, padding='post')
predd3 = model.predict_classes(d3pad).item()

d4pad = vect.texts_to_sequences(d4)
d4pad = pad_sequences(d4pad, maxlen=4, padding='post')
predd4 = model.predict_classes(d4pad).item()

d5pad = vect.texts_to_sequences(d5)
d5pad = pad_sequences(d5pad, maxlen=4, padding='post')
predd5 = model.predict_classes(d5pad)
predd5 = np.argmax(predd5)

d6pad = vect.texts_to_sequences(d6)
d6pad = pad_sequences(d6pad, maxlen=5, padding='post')
predd6 = model.predict_classes(d6pad).item()

d7pad = vect.texts_to_sequences(d7)
d7pad = pad_sequences(d7pad, maxlen=3, padding='post')
predd7 = model.predict_classes(d7pad).item()

d8pad = vect.texts_to_sequences(d8)
d8pad = pad_sequences(d8pad, maxlen=4, padding='post')
predd8 = model.predict_classes(d8pad).item()

d9pad = vect.texts_to_sequences(d9)
d9pad = pad_sequences(d9pad, maxlen=4, padding='post')
predd9 = model.predict_classes(d9pad).item()

d10pad = vect.texts_to_sequences(d10)
d10pad = pad_sequences(d10pad, maxlen=6, padding='post')
predd10 = model.predict_classes(d10pad).item()

d11pad = vect.texts_to_sequences(d11)
d11pad = pad_sequences(d11pad, maxlen=3, padding='post')
predd11 = model.predict_classes(d11pad).item()

d12pad = vect.texts_to_sequences(d12)
d12pad = pad_sequences(d12pad, maxlen=5, padding='post')
predd12 = model.predict_classes(d12pad).item()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print("Text: ",d1, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd1)
print("Text: ",d2, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd2)
print("Text: ",d3, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd3)
print("Text: ",d4, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd4)
print("Text: ",d5, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd5)
print("Text: ",d6, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd6)
print("Text: ",d7, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd7)
print("Text: ",d8, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd8)
print("Text: ",d9, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd9)
print("Text: ",d10, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd10)
print("Text: ",d11, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd11)
print("Text: ",d12, "-->", "Actual Label: ", "0", "-->", "Predicted: ", predd12)
# Out:
# Text:  ['i have lost in life'] --> Actual Label:  0 --> Predicted:  1
# Text:  ['why do i have to be sad'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i have never been so disappointed in life'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i feel like crying'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i hate the world'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['why is everything so hard'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i feel miserable'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i live in a terrible place'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i cry all day'] --> Actual Label:  0 --> Predicted:  0
# Text:  ['i am not lucky nor blessed'] --> Actual Label:  0 --> Predicted:  1
# Text:  ['nobody loves me'] --> Actual Label:  0 --> Predicted:  1
# Text:  ['i am unlucky'] --> Actual Label:  0 --> Predicted:  0

# %%
# Read as a dataframe 
metrics = pd.DataFrame(history.history)
metrics.rename(columns = {'loss': 'Training_Loss', 'accuracy': 'Training_Accuracy', 'val_loss': 'Validation_Loss', 'val_accuracy': 'Validation_Accuracy'}, inplace = True)
def plot_graphs1(var1, var2, string):
    metrics[[var1, var2]].plot()
    plt.title('Training and Validation ' + string)
    plt.xlabel ('Number of epochs')
    plt.ylabel(string)
    plt.legend([var1, var2])

# %%
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
plot_graphs1('Training_Loss', 'Validation_Loss', 'loss')

# %%
plot_graphs1('Training_Accuracy', 'Validation_Accuracy', 'accuracy')

# %% [markdown]
# ### Metrics

# %%
#pred = model.predict(padded_docs_test)
#pred = pred.round()
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[791  46]
#  [ 60 866]]

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in
                cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cm, annot=labels, fmt='', cmap='Blues')

# %%
print(classification_report(y_test,pred))
print("Accuracy: ", accuracy_score(y_test, pred))
print("F1: ", f1_score(y_test, pred))
print("Precision: ", precision_score(y_test, pred))
print("Recall: ", recall_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       837
#            1       0.95      0.94      0.94       926
#
#     accuracy                           0.94      1763
#    macro avg       0.94      0.94      0.94      1763
# weighted avg       0.94      0.94      0.94      1763
#
# Accuracy:  0.9398752127056155
# F1:  0.9423286180631121
# Precision:  0.9495614035087719
# Recall:  0.9352051835853131
